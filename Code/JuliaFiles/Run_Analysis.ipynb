# %%
include("MasterAnalysis.jl")
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:46
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:46
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:47
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:47
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:49
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:53
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:53
# Number of Short-Term Loans for Summary Path is 457
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:54
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:68
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:69
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:69
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:70
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:70
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:84
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:84
# Number of crises with IMF lending is 148
# Number of crises without IMF lending is 118
# Number of total crises for path is 266
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:85
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:85
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:107
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:107
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:107
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:107
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:127
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:127
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:128
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:128
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:129
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:129
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:30
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:36
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:36
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:38
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:38
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#662(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:40
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:168
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:168
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:168
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:168
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:168
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:168
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:171
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at MasterAnalysis.jl:180
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:180
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:190
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:190
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:191
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:191
# Avg Loan Size for Matched Obs: 3.312131877264957
# The number of treated observations with synthetic controls is 117
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = top-level scope at MasterAnalysis.jl:198
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:198
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:201
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:201
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:205
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:205
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:219
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:219
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at MasterAnalysis.jl:219
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:219
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:222
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:222
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at MasterAnalysis.jl:222
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:222
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:234
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:234
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:234
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:234
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:235
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:235
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:235
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:235
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:235
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:235
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:236
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:236
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:236
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:236
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:236
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:236
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:236
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:236
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:237
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:237
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:237
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:237
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:237
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:237
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:237
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:237
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:237
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:237
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:238
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:239
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:239
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:243
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:243
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:243
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:243
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:247
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:247
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:247
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:247
# P value for Hotelling T-sq is 5.948680994417387e-9
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:247
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:247
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:254
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:256
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:256
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:257
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:257
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:276
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:276
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:277
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:277
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:278
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:278
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at MasterAnalysis.jl:283
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:283
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:284
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:284
# Average Cumulative Effect is 10.439323009022301
# BOE multiplier is 3.151844007383767
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:10
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:10
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:11
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:32
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:32
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:32
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:32
# N is 117
# N is 117
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = HeterogeneityScatter(::Symbol) at Heterogeneity_Correlation.jl:17
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Correlation.jl:17
# N is 117
# N is 104
# N is 117
# N is 117
# N is 103
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:20
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:20
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:43
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:43
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:43
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:50
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:50
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at Heterogeneity_Regressions.jl:63
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\Heterogeneity_Regressions.jl:63
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# CumulativeEffect ~ 0 + Africa + SA + EAP + ECA + LAC + MidEast + AmountAgreedPercentGDP + conditions + year + WGI
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────────────────────
#                           Estimate  Std. Error     t value  Pr(>|t|)    Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────────────────────
# Africa                   -5.02198     31.8842   -0.157507     0.8752   -68.3377     58.2938
# SA                       15.7894      59.2072    0.266679     0.7903  -101.784     133.363
# EAP                     -53.7395      45.9614   -1.16923      0.2453  -145.01       37.5306
# ECA                     -11.0876      41.0959   -0.269798     0.7879   -92.696      70.5208
# LAC                       7.81708     27.2059    0.287331     0.7745   -46.2084     61.8426
# MidEast                 -22.4541      46.7682   -0.480115     0.6323  -115.326      70.4182
# AmountAgreedPercentGDP   -0.224097     3.25284  -0.0688927    0.9452    -6.6836      6.2354
# conditions                0.26176      0.38518   0.679578     0.4985    -0.503131    1.02665
# year                     -0.144324     1.4153   -0.101974     0.9190    -2.95483     2.66619
# WGI                      -6.21247     21.6139   -0.287429     0.7744   -49.1335     36.7085
# ────────────────────────────────────────────────────────────────────────────────────────────

# %%
include(joinpath(code_directory, "PlaceboComparisonTable.jl"))
# Out:
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:30
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:36
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:36
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:38
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:38
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#650(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:40
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:59
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:59
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:59
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:59
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:59
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:59
# N is 72
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:61
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:61
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:61
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:61
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:61
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:61
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:74
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:74
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:75
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:75
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:76
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:76
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:77
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:77
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:78
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:78
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at PlaceboComparisonTable.jl:79
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\PlaceboComparisonTable.jl:79
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:30
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:36
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:36
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:38
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:38
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#669(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:40
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# N is 78
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:30
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:36
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:36
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:38
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:38
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#688(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ...
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#1144(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:40
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# N is 87
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:54
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:54
# Excessive output truncated after 524639 bytes.┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29

# %%
include(joinpath(code_directory, "GenSynthetics_NLopt.jl"))
# Out:
# GenSynthetics (generic function with 1 method)

# %%
include(joinpath(code_directory, "RobustnessRuns.jl"))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:9
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:9
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:17
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:17
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:30
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:42
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:42
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:76
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:76
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:110
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:110
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:114
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:114
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#629(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:87
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:87
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:95
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:95
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:96
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:96
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:123
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:123
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:123
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:123
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:133
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:133
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:133
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:133
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:134
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:134
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:134
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:134
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:134
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:134
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:135
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:135
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:135
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:135
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:135
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:135
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:135
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:135
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:136
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:136
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:136
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:136
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:136
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:136
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:136
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:136
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:136
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:136
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:137
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:137
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at RobustnessRuns.jl:138
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:138
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:145
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:145
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:145
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:145
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:147
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:147
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:147
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:147
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:149
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:149
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:149
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:149
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:151
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:151
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:151
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:151
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:153
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:153
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:153
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:153
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:155
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:155
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:155
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:155
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:157
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:157
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:157
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:157
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:159
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:159
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:159
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:159
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:167
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:167
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:167
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:167
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:169
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:169
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:169
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:169
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:171
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:171
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:173
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:173
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at RobustnessRuns.jl:173
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RobustnessRuns.jl:173

# %%
g1 = :maroon #RGB(.1,.1,.1)
g15= :purple2 #RGB(.18, .18, .18)
g2 = :red #RGB(.25,.25,.25)
g3 = :skyblue #RGB(.4,.4,.4)
g4 = :green #RGB(.53,.53,.53)
g45= :springgreen #RGB(.61, .61, .61)
g5 = :orange #RGB(.7,.7,.7)
g6 = :burlywood #RGB(.82,.82, .82)
g7 = :black #RGB(.93,.93,.93)

t = collect(0:1:6)
#---GRAPH WITH ALL ROBUSTNESS (Figure 3b) --------#
plot(t, [0; MainBetas[:,1]], linewidth=2.5, color=treatedblue, grid=false, label="", ylabel="", xlabel="Years From Crisis", legend=(0.1,0.36), legendfontsize=7, ylims=(-3,4.3), marker=([:circle], [treatedblue], [2.5]))
plot!(t, RobustnessChecks[2:end, 1], linewidth=1.75, color=g1, style=:dashdot, label="+CAB", marker=([:hexagon], [g1], [2]))
plot!(t, RobustnessChecks[2:end, 2], linewidth=1.75, color=g15, style=:dashdot, label="+Infl",  marker=([:rect], [g15], [2]))
plot!(t, RobustnessChecks[2:end, 3], linewidth=1.75, color=g2, style=:dot, label="+Debt",  marker=([:xcross], [g2], [2]))
plot!(t, RobustnessChecks[2:end, 4], linewidth=1.75, color=g3, style=:dot, label="Tight Bounds",  marker=([:utriangle], [g3], [2]))
plot!(t, RobustnessChecks[2:end, 5], linewidth=1.75, color=g4, style=:dashdot, label="Wide Bounds",  marker=([:dtriangle], [g4], [2]))
plot!(t, RobustnessChecks[2:end, 6], linewidth=1.75, color=g45, style=:dot, label="Any Crisis Type",  marker=([:star4], [g45], [2]))
plot!(t, RobustnessChecks[2:end, 7], linewidth=1.75, color=g5, style=:dashdot, label="No Adv.",  marker=([:+], [g5], [2]))
plot!(t, RobustnessChecks[2:end, 8], linewidth=1.75, color=g6, style=:dashdot, label="Good Matches",  marker=([:pentagon], [g6], [2]))
plot!(t, RobustnessChecks[2:end, 9], linewidth=1.75, color=g7, style=:dashdot, label="Local Projection", marker=([:star8], [g7], [2]))
hline!([0], color=:black, style=:dot, label="")
savefig(joinpath(output_directory, "Robustness.pdf"))

# %%
using DataFrames

test = DataFrame(A = [2.; 2.]; B = [2.; 2.], C = [1; .])
# Out:
# syntax: invalid identifier name "."

# %%
## LOAD IN ALL IMF LOAN DATA (GROWTH RATES CENTERED AROUND LOAN)
Loans = CSV.read(joinpath(data_directory, "created", "Loans.csv"))
Loans = Loans[Loans[:year].>1969,:]
Loans = Loans[Loans[:year].<2012,:]
#Plot time series of loans vs stabilization loans 
Stabilization_Loans = Loans[Loans[:Shortterm].==1, :]
time_series_years = collect(1970:1:2011)
Loan_Count = zeros(length(time_series_years),2)
for year = 1:size(Loan_Count)[1]
    Loan_Count[year, 1] = size(Loans[Loans[:year].==1969+year,:])[1]
    Loan_Count[year, 2] = size(Stabilization_Loans[Stabilization_Loans[:year].==1969+year,:])[1]
end
plot(time_series_years, Loan_Count, label="", ylabel="Newly Originated IMF Arrangements", xlabel="", linecolor=[treatedblue controlred], linestyle=[:dash :solid], linewidth=[2 2], grid=false)
annotate!([(1996.6, 27, text("All \n Loans", 10, :black, :left))])
annotate!([(1995.9, 15.15, text("Stabilization \n Loans", 10, controlred, :left))])
savefig(joinpath(output_directory, "TimeSeries.pdf"))
#Summary Stats Table
SummaryVars = [:DWDI, :AmountAgreedPercentGDP, :simple_conditions, :CAB, :EXDEBT]
SummaryStats = DataFrame(Varname = [:DWDI], Mean = [10.2], Median = [6.1], StdDev = [6.3], N = [10])
deleterows!(SummaryStats, 1)
  for (i,s) in enumerate(SummaryVars)
    temp_df = Stabilization_Loans[:,[:year, s]]
    temp_df = temp_df[completecases(temp_df),:]
    temp_arry = zeros(1,4)
    temp_arry[1,1] = mean(temp_df[s])
    temp_arry[1,2] = median(temp_df[s])
    temp_arry[1,3] = sqrt(var(temp_df[s]))
    temp_arry[1,4] = size(temp_df)[1]
    push!(SummaryStats, [s temp_arry])
  end
CSV.write(joinpath(output_directory, "SummaryStats.csv"), SummaryStats)

LoanPath = Stabilization_Loans[:, growths]
LoanPath = LoanPath[completecases(LoanPath),:];

## COMPUTE MEAN/MEDIAN GROWTH RATES X YEARS AFTER LOAN
NShortTermComplete = size(LoanPath)[1]
println("Number of Short-Term Loans for Summary Path is $NShortTermComplete")
meanmedLoan = zeros(size(growths)[1],2)
    for (j,g) in enumerate(growths)
        meanmedLoan[j,1] = mean(LoanPath[g])
        meanmedLoan[j,2] = median(LoanPath[g])
    end

# ------ FIGURE 1 -----------------------------------------------------------------------#
colorMean = :black
colorMed = RGB(120/255, 120/255, 120/255)
styleMed = :dashdot
plot(t[1:11], meanmedLoan[1:11,:], label= ["Mean" "Median"], legend=:bottomright, grid=false, color=[colorMean colorMed], style=[:solid styleMed],
linewidth=[2.5 2.5])
vline!([0], color=:black, label="", style=:dot)
xticks!(t)
xlabel!("Years Since Loan")
ylabel!("GDP Growth (%)")
annotate!([(0, 3.8, text("IMF Loan", 9, :black, :left))])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:3
# └ @ Core In[91]:3
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:4
# └ @ Core In[91]:4
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:5
# └ @ Core In[91]:5
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:10
# └ @ Core .\In[91]:10
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:11
# └ @ Core .\In[91]:11
# Number of Short-Term Loans for Summary Path is 457
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:25
# └ @ Core .\In[91]:25
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:26
# └ @ Core .\In[91]:26
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:27
# └ @ Core .\In[91]:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:41
# └ @ Core .\In[91]:41
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[91]:42
# └ @ Core .\In[91]:42

# %%
LoanPath = Loans[:, growths]
# Out:
# 864×13 DataFrame. Omitted printing of 7 columns
# │ Row │ LGrowth5  │ LGrowth4   │ LGrowth3 │ LGrowth2  │ LGrowth1  │ DWDI      │
# │     │ Float64⍰  │ Float64⍰   │ Float64⍰ │ Float64⍰  │ Float64⍰  │ Float64⍰  │
# ├─────┼───────────┼────────────┼──────────┼───────────┼───────────┼───────────┤
# │ 1   │ missing   │ missing    │ missing  │ missing   │ missing   │ missing   │
# │ 2   │ missing   │ missing    │ missing  │ missing   │ missing   │ missing   │
# │ 3   │ missing   │ missing    │ 8.83228  │ 1.41412   │ 11.2297   │ 5.3574    │
# │ 4   │ 5.3574    │ 13.8263    │ 3.92498  │ 21.3905   │ 14.3624   │ 0.426355  │
# │ 5   │ 10.9529   │ 15.0289    │ 11.5477  │ 14.01     │ 11.1661   │ 0.858713  │
# │ 6   │ -0.787843 │ -1.42004   │ 9.83655  │ -9.57564  │ -28.0021  │ -7.18711  │
# │ 7   │ -1.42004  │ 9.83655    │ -9.57564 │ -28.0021  │ -7.18711  │ 9.55941   │
# │ 8   │ 9.55941   │ 8.30287    │ 13.3223  │ 9.1       │ -10.92    │ 8.83009   │
# │ 9   │ -10.92    │ 8.83009    │ 12.8899  │ 6.95004   │ 8.29007   │ 4.53996   │
# │ 10  │ 8.29007   │ 4.53996    │ 5.53005  │ 5.51      │ 5.52991   │ 5.90008   │
# ⋮
# │ 854 │ -3.02393  │ 3.03562    │ 6.16796  │ -2.81278  │ -1.96669  │ -0.336835 │
# │ 855 │ 6.16796   │ -2.81278   │ -1.96669 │ -0.336835 │ 1.61531   │ 0.723894  │
# │ 856 │ -0.481072 │ -0.0361334 │ -1.73092 │ 6.79727   │ -8.62544  │ 2.89767   │
# │ 857 │ -8.62544  │ 2.89767    │ 6.21855  │ 3.81401   │ -0.385746 │ 4.65019   │
# │ 858 │ 4.65019   │ 3.89732    │ 5.31687  │ 4.50601   │ 6.94497   │ 7.03239   │
# │ 859 │ 6.94497   │ 7.03239    │ 7.2356   │ 7.90369   │ 8.35244   │ 7.7739    │
# │ 860 │ 0.464839  │ -6.8607    │ -2.70692 │ 3.29704   │ 14.4207   │ 12.5254   │
# │ 861 │ -2.70692  │ 3.29704    │ 14.4207  │ 12.5254   │ 2.6343    │ 1.58531   │
# │ 862 │ 1.15074   │ 7.55237    │ 5.19977  │ 6.98855   │ 5.53178   │ -9.01557  │
# │ 863 │ 1.05146   │ 9.2352     │ 0.158026 │ 10.3607   │ 2.68059   │ 2.88521   │
# │ 864 │ 9.2352    │ 0.158026   │ 10.3607  │ 2.68059   │ 2.88521   │ -0.817821 │

# %%
SyntheticPlacebos
# Out:
# 73×26 DataFrame. Omitted printing of 22 columns
# │ Row │ Country                      │ year  │ LGrowth5  │ LGrowth4   │
# │     │ String                       │ Int64 │ Float64⍰  │ Float64⍰   │
# ├─────┼──────────────────────────────┼───────┼───────────┼────────────┤
# │ 1   │ Synthetic Angola             │ 1988  │ 4.73578   │ 6.91827    │
# │ 2   │ Synthetic Angola             │ 1991  │ 3.81862   │ 4.37588    │
# │ 3   │ Synthetic Argentina          │ 1980  │ 2.95268   │ 0.00657422 │
# │ 4   │ Synthetic Austria            │ 2008  │ 0.941469  │ 2.73512    │
# │ 5   │ Synthetic Burundi            │ 1994  │ 3.70298   │ 2.67933    │
# │ 6   │ Synthetic Belgium            │ 2008  │ 1.03795   │ 3.57119    │
# │ 7   │ Synthetic Belize             │ 2007  │ 5.38777   │ 6.27462    │
# │ 8   │ Synthetic Brazil             │ 1976  │ 9.54715   │ 11.7329    │
# │ 9   │ Synthetic Brazil             │ 1994  │ 2.03378   │ 0.165079   │
# │ 10  │ Synthetic Botswana           │ 1984  │ 10.9437   │ 11.8329    │
# ⋮
# │ 63  │ Synthetic New Zealand        │ 1984  │ 2.19232   │ 1.28415    │
# │ 64  │ Synthetic Panama             │ 1988  │ 2.71763   │ 3.54412    │
# │ 65  │ Synthetic Peru               │ 1988  │ -3.18026  │ 5.09124    │
# │ 66  │ Synthetic Philippines        │ 1997  │ 1.82414   │ 2.99119    │
# │ 67  │ Synthetic Portugal           │ 2008  │ -0.217964 │ 1.91311    │
# │ 68  │ Synthetic Paraguay           │ 1982  │ 2.72288   │ 8.21102    │
# │ 69  │ Synthetic Paraguay           │ 1984  │ 7.86842   │ 9.07557    │
# │ 70  │ Synthetic Paraguay           │ 1989  │ 3.03778   │ 4.63003    │
# │ 71  │ Synthetic Paraguay           │ 1995  │ 4.05378   │ 3.46546    │
# │ 72  │ Synthetic Russian Federation │ 2008  │ 7.25797   │ 7.24909    │
# │ 73  │ Synthetic Sudan              │ 1988  │ 2.56039   │ 0.568965   │
