# %%
include("MasterAnalysis.jl")
# Out:
# Mean Loan Size is 2.004868954005943
# Median Loan Size is 1.2309605
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Number of Short-Term Loans for Summary Path is 458
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Number of total crises for path is 328
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Number of crises with IMF lending is 144
# Number of crises without IMF lending is 132
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Number of total crises for path is 276
# ┌ Warning: indexing with colon as row will create a copy of rows in the future
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:18
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\RunningPlacebosFunction.jl:18
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:23
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\RunningPlacebosFunction.jl:23
# Another One!
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# Angola 1988 has local matches!
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:100
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:100
# Pushed Synthetic
# Pushed Treated
# Another One!
# Angola 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Angola 1996 has no local matches
# Another One!
# Albania 1990 has no local matches
# Another One!
# Argentina 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Austria 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Burundi 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Belgium 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Belarus 1999 has no local matches
# Another One!
# Brazil 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Brazil 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Brazil 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Botswana 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Central African Republic 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Switzerland 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Chile 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# China 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Congo, Dem. Rep. 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Congo, Dem. Rep. 1994 has no local matches
# Another One!
# Congo, Dem. Rep. 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Congo, Rep. 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Colombia 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Colombia 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Comoros 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Cabo Verde 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Czech Republic 1996 has no local matches
# Another One!
# Germany 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Denmark 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Ecuador 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Egypt, Arab Rep. 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Spain 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Spain 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Finland 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Finland 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Fiji 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# France 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Gabon 2002 has no local matches
# Another One!
# United Kingdom 2007 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Georgia 1991 has no local matches
# Another One!
# Georgia 1999 has no local matches
# Another One!
# Ghana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Guinea 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Guinea 2005 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Guinea-Bissau 1980 has no local matches
# Another One!
# Another One!
# Greece 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Greece 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Grenada 2004 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Guatemala 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Guyana 1982 has no local matches
# Another One!
# Guyana 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Haiti 2003 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Indonesia 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# India 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Ireland 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Iran, Islamic Rep. 1985 has no local matches
# Another One!
# Iran, Islamic Rep. 1992 has no local matches
# Another One!
# Iran, Islamic Rep. 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Another One!
# Another One!
# Israel 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Israel 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Italy 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Italy 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Jamaica 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Japan 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Kazakhstan 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Another One!
# Kuwait 1982 has no local matches
# Another One!
# Another One!
# Another One!
# Another One!
# Lao PDR 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Another One!
# Liberia 1991 has no local matches
# Another One!
# Another One!
# Lesotho 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Luxembourg 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Moldova 2002 has no local matches
# Another One!
# Madagascar 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Madagascar 2004 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Another One!
# Mali 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Malta 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Malta 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Myanmar 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Myanmar 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Myanmar 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Malaysia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Nigeria 1983 has no local matches
# Another One!
# Nigeria 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Nigeria 2009 has no local matches
# Another One!
# Nicaragua 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Nicaragua 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Netherlands 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Norway 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# New Zealand 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Panama 1988 has no local matches
# Another One!
# Peru 1988 has no local matches
# Another One!
# Philippines 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Portugal 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Paraguay 1982 has no local matches
# Another One!
# Paraguay 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Paraguay 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Paraguay 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Russian Federation 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Sudan 1988 has no local matches
# Another One!
# Sudan 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Sierra Leone 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Sierra Leone 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# El Salvador 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Another One!
# Another One!
# Suriname 1990 has no local matches
# Another One!
# Suriname 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Suriname 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Slovak Republic 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Another One!
# Slovenia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Another One!
# Sweden 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Albania 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# ┌ Warning: Duplicate variable names are deprecated: pass makeunique=true to add a suffix automatically.
# │   caller = ip:0x0
# └ @ Core :-1
# Argentina 1989 has no local matches
# Argentina 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 2001 has no local matches
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has no local matches
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Spain 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has no local matches
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has no local matches
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guyana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Hungary 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Indonesia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Iceland 2008 has no local matches
# Israel 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1978 has no local matches
# Jamaica 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 2010 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Liberia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Latvia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has no local matches
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mali 1987 has no local matches
# Mongolia 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Pakistan 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Panama 1983 has no local matches
# Peru 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1978 has no local matches
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1983 has no local matches
# Uruguay 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 2002 has no local matches
# Uzbekistan 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Venezuela, RB 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zambia 1983 has no local matches
# Zambia 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# The number of treated observations with synthetic controls is 99
# There are 154 in the horizon 1 Forecasting regression
# There are 154 in the horizon 2 Forecasting regression
# There are 154 in the horizon 3 Forecasting regression
# There are 154 in the horizon 4 Forecasting regression
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Albania 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1987 has local matches!
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:100
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:100
# Pushed Synthetic
# Pushed Treated
# Argentina 1989 has no local matches
# Argentina 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 2001 has no local matches
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has no local matches
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Spain 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has no local matches
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has no local matches
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guyana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Hungary 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Indonesia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Iceland 2008 has no local matches
# Israel 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1978 has no local matches
# Jamaica 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 2010 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Latvia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has no local matches
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mali 1987 has no local matches
# Mongolia 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Panama 1983 has no local matches
# Peru 1978 has no local matches
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has no local matches
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1983 has no local matches
# Uruguay 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 2002 has no local matches
# Venezuela, RB 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zambia 1983 has no local matches
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Albania 1997 has local matches!
# Pushed Synthetic
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has no local matches
# Bolivia 1980 has no local matches
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has no local matches
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Spain 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has no local matches
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has no local matches
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Hungary 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Indonesia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Iceland 2008 has no local matches
# Israel 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1978 has no local matches
# Jamaica 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 2010 has no local matches
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Latvia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has no local matches
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Pakistan 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Panama 1983 has no local matches
# Peru 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1978 has no local matches
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1983 has no local matches
# Uruguay 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 2002 has no local matches
# Zambia 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Albania 1997 has local matches!
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# Pushed Synthetic
# Pushed Treated
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has no local matches
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has no local matches
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has no local matches
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has no local matches
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guyana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Indonesia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1978 has no local matches
# Jamaica 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 2010 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Liberia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has no local matches
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mali 1987 has no local matches
# Mongolia 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Pakistan 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1978 has no local matches
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uzbekistan 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Venezuela, RB 1989 has no local matches
# Zambia 1983 has no local matches
# Zambia 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Albania 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 2001 has no local matches
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has no local matches
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Spain 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guyana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# ...
# Jamaica 2010 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Liberia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Latvia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mali 1987 has no local matches
# Mongolia 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mozambique 1987 has no local matches
# Malawi 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Pakistan 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Panama 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Portugal 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sudan 1979 has no local matches
# Sudan 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1983 has no local matches
# Uruguay 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 2002 has no local matches
# Uzbekistan 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Venezuela, RB 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zambia 1983 has no local matches
# Zambia 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Albania 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1989 has no local matches
# Argentina 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 2001 has no local matches
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has no local matches
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cameroon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Dem. Rep. 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Colombia 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Costa Rica 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominica 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Algeria 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Spain 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gabon 1986 has no local matches
# Gabon 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 1978 has no local matches
# Ghana 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ghana 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Gambia, The 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guinea-Bissau 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Guyana 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Honduras 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Hungary 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Indonesia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Iceland 2008 has no local matches
# Israel 1975 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1978 has no local matches
# Jamaica 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jamaica 2010 has local matches!
# Pushed Synthetic
# Pushed Treated
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1985 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kenya 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Liberia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sri Lanka 1978 has local matches!
# Pushed Synthetic
# Pushed Treated
# Latvia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Morocco 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1981 has no local matches
# Madagascar 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Madagascar 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mexico 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mali 1987 has no local matches
# Mongolia 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mongolia 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Nepal 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Pakistan 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Panama 1983 has no local matches
# Peru 1976 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1978 has no local matches
# Peru 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Peru 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# Paraguay 2002 has local matches!
# Pushed Synthetic
# Pushed Treated
# Romania 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Senegal 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1977 has local matches!
# Pushed Synthetic
# Pushed Treated
# Sierra Leone 1983 has local matches!
# Pushed Synthetic
# Pushed Treated
# El Salvador 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local matches!
# Pushed Synthetic
# Pushed Treated
# Togo 1993 has local matches!
# Pushed Synthetic
# Pushed Treated
# Thailand 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Turkey 2000 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uganda 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Ukraine 1998 has no local matches
# Ukraine 2008 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1972 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1981 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 1983 has no local matches
# Uruguay 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Uruguay 2002 has no local matches
# Uzbekistan 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Venezuela, RB 1989 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zambia 1983 has no local matches
# Zambia 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local matches!
# Pushed Synthetic
# Pushed Treated
# Zimbabwe 1998 has local matches!
# Pushed Synthetic
# Pushed Treated
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# Albania 1997 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1975 has local matches!
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#28(::Float64, ::Array{Int64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:100
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:100
# Pushed Synthetic
# Pushed Treated
# Argentina 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 1989 has no local matches
# Argentina 1995 has local matches!
# Pushed Synthetic
# Pushed Treated
# Argentina 2001 has local matches!
# Pushed Synthetic
# Pushed Treated
# Benin 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Burkina Faso 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bangladesh 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1990 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bulgaria 1996 has local matches!
# Pushed Synthetic
# Pushed Treated
# Belarus 2009 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1973 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1980 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1986 has local matches!
# Pushed Synthetic
# Pushed Treated
# Bolivia 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1982 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1987 has local matches!
# Pushed Synthetic
# Pushed Treated
# Brazil 1992 has local matches!
# Pushed Synthetic
# Pushed Treated
# Central African Republic 1994 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1984 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1988 has local matches!
# Pushed Synthetic
# Pushed Treated
# Cote d'Ivoire 1994 has local matches!

# %%
include("RobustnessAppendixFigure.jl")
# Out:
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#81(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#81(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#81(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#81(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:70
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:70
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#81(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:99
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:99
# Argentina 1989 has no local matches
# Argentina 2001 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Bolivia 1973 has no local matches
# Cote d'Ivoire 1984 has no local matches
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Guinea 1985 has no local matches
# Gambia, The 1985 has no local matches
# Haiti 1994 has no local matches
# Iceland 2008 has no local matches
# Jamaica 1978 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Liberia 1980 has no local matches
# Moldova 1999 has no local matches
# Madagascar 1981 has no local matches
# Mali 1987 has no local matches
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Poland 1992 has no local matches
# Paraguay 2002 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Serbia 2000 has no local matches
# Seychelles 2008 has no local matches
# Togo 1993 has no local matches
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 1983 has no local matches
# Uruguay 2002 has no local matches
# Yemen, Rep. 1995 has no local matches
# Zambia 1983 has no local matches
# Zambia 1995 has no local matches
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = top-level scope at none:0
# └ @ Core none:0
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:70
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:70
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,1}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:99
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:99
# Argentina 1989 has no local matches
# Argentina 2001 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominican Republic 1990 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Iceland 2008 has no local matches
# Jamaica 1978 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Madagascar 1981 has no local matches
# Mali 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Panama 1983 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1993 has no local matches
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 1983 has no local matches
# Uruguay 2002 has no local matches
# Zambia 1983 has no local matches
# Zimbabwe 1983 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Bolivia 1973 has no local matches
# Bolivia 1980 has no local matches
# Cote d'Ivoire 1984 has no local matches
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominica 2002 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Iceland 2008 has no local matches
# Jamaica 1978 has no local matches
# Jamaica 2010 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Madagascar 1981 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Panama 1983 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 1983 has no local matches
# Uruguay 2002 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Bolivia 1973 has no local matches
# Cote d'Ivoire 1984 has no local matches
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominican Republic 1990 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Jamaica 1978 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Madagascar 1981 has no local matches
# Mali 1987 has no local matches
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Chad 1994 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Venezuela, RB 1989 has no local matches
# Zambia 1983 has no local matches
# Zimbabwe 1983 has no local matches
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:24
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:24
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:25
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:25
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:41
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:41
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:70
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:70
# ┌ Warning: indexing with colon as row will create a copy in the future use df[col_inds] to get the columns without copying
# │   caller = #GenSynthetics#88(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::Function, ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:99
# └ @ Main C:\Users\kevin\OneDrive\IMF\Code\JuliaFiles\GenSynthetics_NLopt.jl:99
# Argentina 1989 has no local matches
# Argentina 2001 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Bolivia 1973 has no local matches
# Cote d'Ivoire 1984 has no local matches
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Iceland 2008 has no local matches
# Jamaica 1978 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Madagascar 1981 has no local matches
# Mali 1987 has no local matches
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Panama 1983 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 1983 has no local matches
# Uruguay 2002 has no local matches
# Venezuela, RB 1989 has no local matches
# Zambia 1983 has no local matches
# Zimbabwe 1983 has no local matches
# Argentina 1989 has no local matches
# Argentina 2001 has no local matches
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Bolivia 1973 has no local matches
# Cote d'Ivoire 1984 has no local matches
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Rep. 1986 has no local matches
# Costa Rica 1981 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Gabon 1986 has no local matches
# Ghana 1978 has no local matches
# Iceland 2008 has no local matches
# Jamaica 1978 has no local matches
# Jordan 1989 has no local matches
# Kyrgyz Republic 1997 has no local matches
# Madagascar 1981 has no local matches
# Mali 1987 has no local matches
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Panama 1983 has no local matches
# Peru 1978 has no local matches
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Russian Federation 1998 has no local matches
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 1983 has no local matches
# Uruguay 2002 has no local matches
# Zambia 1983 has no local matches
# Zimbabwe 1983 has no local matches
# Argentina 2001 has no local matches
# Dominican Republic 2003 has no local matches
# Ecuador 1982 has no local matches
# Jordan 1989 has no local matches
# Niger 1983 has no local matches
# Philippines 1983 has no local matches
# Russian Federation 1998 has no local matches
# Ukraine 1998 has no local matches
# Uruguay 2002 has no local matches

# %%
#############################################################
# Th#######################################################
# This is a master file that runs all analysis for          #
# "Are IMF Rescue Packages Effective? Evidence From Crises" #
#  All findings and figures can be produced by running this #
# code with the appropriate data and julia functions within #
# the folder.                                               #
#############################################################

directory = dirname(dirname(pwd()))
code_directory = joinpath(directory, "Code", "JuliaFiles")
data_directory = joinpath(directory, "Data")
output_directory = joinpath(directory, "Results")
mkpath(output_directory)

using Plots
using Statistics
using ColorTypes
using DataFrames
using CSV
using Ipopt
using NLopt
using LinearAlgebra
using StatsPlots
using Distributions
include(joinpath(code_directory, "LinearRegression.jl"))
include(joinpath(code_directory, "RunningPlacebosFunction.jl"))
include(joinpath(code_directory, "Crisis_Heterogeneity.jl"))


#############################################################
# Things to define for entire paper                         #
#############################################################
t = collect(-5:1:6)
growths = [:LGrowth5, :LGrowth4, :LGrowth3, :LGrowth2, :LGrowth1, :DWDI, :FGrowth1, :FGrowth2, :FGrowth3, :FGrowth4, :FGrowth5, :FGrowth6]
treatedblue = :black
controlred = RGB(120/255, 120/255, 120/255)


#############################################################
# Summary Stats												#
#############################################################

## LOAD IN ALL IMF LOAN GROWTH RATES CENTERED AROUND THEIR LOAN
LoanPath = CSV.read(joinpath(data_directory, "created", "AvgPathLoans.csv"))
tempk = [:AmountAgreedPercentGDP, :year]
LoanSizes  = LoanPath[:, tempk]
LoanSizes  = LoanSizes[completecases(LoanSizes),:]
LoanSizes  = LoanSizes[LoanSizes[:AmountAgreedPercentGDP].>0,:]
AvgSize = mean(LoanSizes[:AmountAgreedPercentGDP])
MedSize = median(LoanSizes[:AmountAgreedPercentGDP])
println("Mean Loan Size is $AvgSize")
println("Median Loan Size is $MedSize")
LoanPath = LoanPath[:, growths]
LoanPath = LoanPath[completecases(LoanPath),:];

## COMPUTE MEAN/MEDIAN GROWTH RATES X YEARS AFTER LOAN
NShortTermComplete = size(LoanPath)[1]
println("Number of Short-Term Loans for Summary Path is $NShortTermComplete")
meanmedLoan = zeros(size(growths)[1],2)
    for (j,g) in enumerate(growths)
        meanmedLoan[j,1] = mean(LoanPath[g])
        meanmedLoan[j,2] = median(LoanPath[g])
    end

## MAKE PLOT
colorMean = :black
colorMed = RGB(120/255, 120/255, 120/255)
styleMed = :dashdot
plot(t[1:11], meanmedLoan[1:11,:], label= ["Mean" "Median"], legend=:bottomright, color=[colorMean colorMed], style=[:solid styleMed],
linewidth=[2.5 2.5])
vline!([0], color=:black, label="", style=:dot)
xticks!(t)
xlabel!("Years Since Loan")
ylabel!("GDP Growth (%)")
annotate!([(0, 3.8, text("IMF Loan", 9, :black, :left))])
savefig(joinpath(output_directory, "SummaryPath.pdf"))

#########################################################################################
#  Make Graph with Financial Crisis & Split to With/Without                             #
#########################################################################################

AllData					= CSV.read(joinpath(data_directory, "created", "MasterData.csv"))
NAllCrises 				= size(AllData)[1]
println("Number of total crises for path is $NAllCrises")
		for z in (:Banking, :Currency, :Debt)
       		AllData[z] = AllData[z]*.5*2
		end
IMFCrises 				= AllData[AllData[:, :IMF].==1, :]
IMFCrisesGrowths		= IMFCrises[:,growths]
IMFCrisesGrowths 		= IMFCrises[completecases(IMFCrisesGrowths), :]
NIMF 					= size(IMFCrisesGrowths)[1]
println("Number of crises with IMF lending is $NIMF")
NoIMFCrises				= AllData[AllData[:, :IMF].==0, :]
NoIMFCrisesGrowths 		= NoIMFCrises[:,growths]
NoIMFCrisesGrowths 		= NoIMFCrises[completecases(NoIMFCrisesGrowths), :]
NNoIMF 					= size(NoIMFCrisesGrowths)[1]
println("Number of crises without IMF lending is $NNoIMF")
AllCrises				= AllData[:, :]
AllCrisesGrowths 		= AllCrises[:,growths]
AllCrisesGrowths 		= AllCrises[completecases(AllCrisesGrowths), :]
NAllCrises 				= size(AllCrisesGrowths)[1]
println("Number of total crises for path is $NAllCrises")

CrisisPaths = zeros(size(growths)[1],3)
    for (j,g) in enumerate(growths)
        CrisisPaths[j,1] = mean(AllCrisesGrowths[g])
        CrisisPaths[j,2] = mean(IMFCrisesGrowths[g])
        CrisisPaths[j,3] = mean(NoIMFCrisesGrowths[g])
    end
plot(t[1:11], CrisisPaths[1:11,1], legend=:bottomright, label="", color=:black, style=:solid, linewidth=2, ylim=(0, 4.4))
vline!([0], color=:black, label="", style=:dot)
xticks!(t)
xlabel!("Years Since Crisis")
ylabel!("GDP Growth (%)")
annotate!([(0, 3.4, text("Crisis Date", 9, :black, :left))])
savefig(joinpath(output_directory, "AvgPathCrises_AllCrises.pdf"))

plot(t[1:11], CrisisPaths[1:11,2:3], legend=:bottomright, label=["W/ IMF" "W/o IMF"], color=[treatedblue controlred], style=[:solid :dashdot], linewidth=[2 2], ylim=(0, 4.4))
vline!([0], color=:black, label="", style=:dot)
xticks!(t)
xlabel!("Years Since Crisis")
ylabel!("GDP Growth (%)")
savefig(joinpath(output_directory, "AvgPathCrises_WithWithout.pdf"))

#########################################################################################
# Run Synthetic Control and Make Graphs (Both Main and Appendix)						#
#########################################################################################

## FIRST DEFINE MAIN SPECIFICATION FOR CONSTRUCTING SYNTHETIC CONTROLS
W 		= ones(10,1)  #diaganol of weighting matrix (equal weights in baseline)
matchon = [:LGrowth5, :LGrowth4, :LGrowth3, :LGrowth2, :LGrowth1, :DWDI, :Banking, :Currency, :Debt]
predict = [:FGrowth1, :FGrowth2, :FGrowth3, :FGrowth4, :FGrowth5, :FGrowth6]
matchtol= Inf	  ### For if I want to throw away bad matches 
bounds  = [7, 7, 7, 7, 7, 7, .5, .5, .5]

## PLACEBO GROUP COMES FIRST IN ORDER TO GENERATE VARIANCE UNDER THE NULL
include("RunningPlacebosFunction.jl")
(Placebos, SyntheticPlacebos) = RunningPlacebos(matchon, W, bounds, predict, NoIMFCrises);

NullErrors = DataFrame()
NullErrors[:PostError1] = map((x,y) -> x-y, Placebos[:PostGrowth1], SyntheticPlacebos[:PostGrowth1])
NullErrors[:PostError2] = map((x,y) -> x-y, Placebos[:PostGrowth2], SyntheticPlacebos[:PostGrowth2])
NullErrors[:PostError3] = map((x,y) -> x-y, Placebos[:PostGrowth3], SyntheticPlacebos[:PostGrowth3])
NullErrors[:PostError4] = map((x,y) -> x-y, Placebos[:PostGrowth4], SyntheticPlacebos[:PostGrowth4])
NullErrors[:PostError5] = map((x,y) -> x-y, Placebos[:PostGrowth5], SyntheticPlacebos[:PostGrowth5])
NullErrors[:PostError6] = map((x,y) -> x-y, Placebos[:PostGrowth6], SyntheticPlacebos[:PostGrowth6])

NullErrorsArray			= convert(Array, [NullErrors[:PostError1] NullErrors[:PostError2] NullErrors[:PostError3] NullErrors[:PostError4] NullErrors[:PostError5] NullErrors[:PostError6]])

###########################################
# AM I DOING THIS VARIANCE (BELOW) RIGHT? #
###########################################
NullCovariance 			= (1/size(NullErrorsArray)[1])*NullErrorsArray'*NullErrorsArray  #calculate variance by hand assuming mean zero

## APPENDIX GRAPH OF PLACEBOS VS THEIR SYNTHETICS FOR GROWTH RATES
PlaceboGrowthRatesArray = convert(Array, Placebos[growths])
SyntheticPlacebosGrowthRatesArray = convert(Array, SyntheticPlacebos[growths])
MeanPlaceboVsSynthetics	= zeros(size(growths)[1],2)
		for j = 1:size(growths)[1]
				MeanPlaceboVsSynthetics[j,1] = mean(PlaceboGrowthRatesArray[:,j])
				MeanPlaceboVsSynthetics[j,2] = mean(SyntheticPlacebosGrowthRatesArray[:,j])
		end
plot(t, MeanPlaceboVsSynthetics, linewidth=[2.5 2], color=[treatedblue controlred], label=["\"Treated\"" "Synthetic"],xticks=collect(-5:1:5), ylabel="Percentage Points", xlabel="Years Since Crisis", style=[:solid :dashdot], legend=:bottomleft)
vline!([0], linestyle=:dash, linewidth=.75, color=:black, label="")
savefig(joinpath(output_directory, "PlaceboGrowthRates.pdf"))


## NOW THAT I HAVE NULL VARIANCES I CAN MOVE TO RUNNING ACTUAL SYNTHETICS
(TreatedMatched, Synthetics, DonorWeights) = GenSynthetics(IMFCrises, NoIMFCrises, matchon, predict, localtol=bounds, matchweights=W);

## PRESENT SOME MATCH 'DIAGNOSTICS', i.e., WHO ACTUALLY CAN GET MATCHED WELL IN PRE-PERIOD
WeightsArray = convert(Array, DonorWeights[:,4:end])
synthtot = size(WeightsArray)[1]
TotalWeight = zeros(synthtot)
for i = 1:synthtot
    TotalWeight[i] = sum(WeightsArray[i,:])
end
DonorWeights[:TotalWeight] = TotalWeight
culprit = DonorWeights[DonorWeights[:TotalWeight].>3.5, :]
#print(culprit)  # Its Venezuala 1982 who didn't have a big collapse
histogram(TotalWeight, bins=30, xticks=collect(0:1:5), color=treatedblue, label="", ylabel="Frequency"
, xlabel="Total (Sum) of Weights in the 99 Synthetics", guidefont=9)
vline!([size(TreatedMatched)[1]/NNoIMF], color=controlred, label="Equal Weights Baseline", style=:dot, linewidth=2)
savefig(joinpath(output_directory, "Histogram.pdf"))

## MAKE TABLE OF NON-TARGETED MOMENTS
#First keep any obs that have full growth rates
EligibleDonors = NoIMFCrises
EligibleDonors[:ID] = collect(1:1:size(EligibleDonors)[1])
tabletemp = [growths; :ID]
CompleteDonors = EligibleDonors[:, tabletemp]
CompleteDonors = CompleteDonors[completecases(CompleteDonors), :]
EligibleDonors = join(EligibleDonors, CompleteDonors, on=:ID, kind=:inner, makeunique=true)

## NOW MAKE TABLE
foravg = [:EXDEBT, :CAB, :GDPRank, :pop, :Gshare, :Infl]
k = length(foravg)
avg = ones(k,2)
dataset = (TreatedMatched, EligibleDonors)
for h = 1:k
	for (y,z) in enumerate(dataset)
		if y==1
		weightsforaverage = (1/size(TreatedMatched)[1])*ones(size(TreatedMatched)[1])
		else
		weightsforaverage = TotalWeight./sum(TotalWeight)
		end
	values = convert(Array, z[foravg[h]])
		for j = 1:size(z)[1]
			if typeof(z[j,foravg[h]])==Missing
			values[j] = 0
			weightsforaverage[j]=0
			end
		end
	weightsforaverage = weightsforaverage/sum(weightsforaverage)
	avg[h,y] = weightsforaverage'*values
	end
end 

AvgTable = ["" "Treated" "Synthetics"; foravg avg]

PreDiff = DataFrame(Country= TreatedMatched[:Country], year = TreatedMatched[:year], PreReal = TreatedMatched[:DWDI], PreSynth = Synthetics[:DWDI])
scatter(PreDiff[:PreReal], PreDiff[:PreSynth], xlabel="Actual t-2 Growth Rate", ylabel="Synthetic t-2 Growth Rate", label="", markersize=1.5, legend=:topleft)
tempx = collect(-10:.05:12)
tempy = tempx
ylo = tempx .- 2.5
yhi = tempx .+ 2.5
plot!(tempx, tempy, label="y=x", style=:solid, color=:black, ylims=(-15, 15))
savefig(joinpath(output_directory, "Diagnostic.pdf"))
plot!(tempx,[ylo yhi], label=["+/- 2.5" ""], style=[:dot :dot], color=:black, ylims=(-15,15))
savefig(joinpath(output_directory, "DiagnosticRobustness.pdf"))

## BEFORE/AFTER GROWTH RATES

TreatedGrowthRatesArray		= convert(Array, TreatedMatched[growths])
NMainRuns					= size(TreatedMatched)[1]
println("The number of treated observations with synthetic controls is $NMainRuns")
SyntheticsGrowthRatesArray 	= convert(Array, Synthetics[growths])
MeanTreatedVsSynthetics		= zeros(size(growths)[1],2)
		for j = 1:size(growths)[1]
				MeanTreatedVsSynthetics[j,1] = mean(TreatedGrowthRatesArray[:,j])
				MeanTreatedVsSynthetics[j,2] = mean(SyntheticsGrowthRatesArray[:,j])
		end
plot(t, MeanTreatedVsSynthetics, linewidth=[2.5 2], color=[treatedblue controlred], label=["Treated" "Synthetic"],xticks=collect(-5:1:size(predict)[1]), ylabel="Percentage Points", xlabel="Years Since Crisis", style=[:solid :dashdot], legend=:bottomleft)
vline!([0], linestyle=:dashdot, linewidth=.75, color=:black, label="")
savefig(joinpath(output_directory, "TreatedGrowthRates.pdf"))


for z = (TreatedMatched, Synthetics)
      z[:PostGrowth1] = map((x1) -> 100*(1+x1/100 -1), z[:FGrowth1])
      z[:PostGrowth2] = map((x1,x2) -> 100*((1+x1/100)*(1+x2/100) -1), z[:FGrowth1], z[:FGrowth2])
      z[:PostGrowth3] = map((x1,x2,x3) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3])
      z[:PostGrowth4] = map((x1,x2,x3,x4) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4])
      z[:PostGrowth5] = map((x1,x2,x3,x4,x5) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100)*(1+x5/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4], z[:FGrowth5])
      z[:PostGrowth6] = map((x1,x2,x3,x4,x5, x6) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100)*(1+x5/100)*(1+x6/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4], z[:FGrowth5], z[:FGrowth6])
end

MainDiffDataFrame = DataFrame(Country = TreatedMatched[:Country], year = TreatedMatched[:year])
MainDiffDataFrame[:LevelDiff1] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth1], Synthetics[:PostGrowth1])
MainDiffDataFrame[:LevelDiff2] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth2], Synthetics[:PostGrowth2])
MainDiffDataFrame[:LevelDiff3] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth3], Synthetics[:PostGrowth3])
MainDiffDataFrame[:LevelDiff4] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth4], Synthetics[:PostGrowth4])
MainDiffDataFrame[:LevelDiff5] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth5], Synthetics[:PostGrowth5])
MainDiffDataFrame[:LevelDiff6] = map((x1, x2) -> x1-x2, TreatedMatched[:PostGrowth6], Synthetics[:PostGrowth6])
MainBetas = zeros(size(predict)[1])
N = size(MainDiffDataFrame)[1]
LDs = [:LevelDiff1, :LevelDiff2, :LevelDiff3, :LevelDiff4, :LevelDiff5, :LevelDiff6]
		for (z, w) in enumerate(LDs)
			MainBetas[z] = mean(MainDiffDataFrame[w])
		end
BetasWithStdErrors = zeros(size(predict)[1],2)
		for k = 1:size(predict)[1]
			BetasWithStdErrors[k,1] = MainBetas[k] - sqrt(NullCovariance[k,k]/N)
			BetasWithStdErrors[k,2] = MainBetas[k] + sqrt(NullCovariance[k,k]/N)
		end

#------ Hoteling T-sq for joint significance of first 5 coefficients ------- #
HotellingT = N*MainBetas'*inv(NullCovariance)*MainBetas
TranslatedToFDist = HotellingT*(N-6)/((N-1)*6) 
### Check p value of this number on F-dist(6,N-6)
F = FDist(6, N-6)
PVal = ccdf(F, TranslatedToFDist)

plot(collect(0:1:size(predict)[1]), [0; MainBetas], linewidth=2.5, color=:black, label="", ylabel="Increase in Output (%)", xlabel="Years From Crisis", marker=([:circle], [:black], [2.5]))
plot!(collect(0:1:size(predict)[1]), [[0; BetasWithStdErrors[:,1]] [0; BetasWithStdErrors[:,2]]], color=:gray, linestyle = :dot, label=["1 s.e." ""], legend=:bottomleft, ylims=(-3, 4.75))
hline!([0], color=:black, style=:dot, label="")
savefig(joinpath(output_directory, "MainIRF.pdf"))

density(MainDiffDataFrame[:LevelDiff2], color=treatedblue, yticks=nothing, xlabel="Level Difference", label="t=2", legend=:topleft, style=:solid, linewidth=2)
density!(MainDiffDataFrame[:LevelDiff3], color=treatedblue, style=:dashdot, label="t=3", linewidth=2)
density!(MainDiffDataFrame[:LevelDiff4], color=treatedblue, style=:dot, label="t=4", linewidth=2)
vline!([0], color=:black, style=:dot, label="")
savefig(joinpath(output_directory, "MainDensity.pdf"))

# -------- Cumulative Effect Size By Treated ------- $
TreatedMatched[:CumulativeEffect] = map((x1,x2,x3,x4,x5) -> +(x1, x2, x3, x4, x5), MainDiffDataFrame[:LevelDiff1], MainDiffDataFrame[:LevelDiff2], MainDiffDataFrame[:LevelDiff3], MainDiffDataFrame[:LevelDiff4], MainDiffDataFrame[:LevelDiff5])
MainMean = mean(TreatedMatched[:CumulativeEffect])
println("Average Cumulative Effect is $MainMean")

# -------- Heterogeneity Results ------------------- #

# -- By Crisis -- #
#CrisisAverages = ByCrisisType()
HeterogeneityScatter(:WGI)
HeterogeneityScatter(:conditions)
# Out:
# This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.
# Mean Loan Size is 2.004868954005943
# Median Loan Size is 1.2309605
# Number of Short-Term Loans for Summary Path is 458
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:49
# └ @ Core In[137]:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:50
# └ @ Core In[137]:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:51
# └ @ Core In[137]:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:62
# └ @ Core .\In[137]:62
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:63
# └ @ Core .\In[137]:63
# Number of total crises for path is 326
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:87
# └ @ Core .\In[137]:87
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:87
# └ @ Core .\In[137]:87
# Number of crises with IMF lending is 144
# Number of crises without IMF lending is 130
# Number of total crises for path is 274
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:107
# └ @ Core .\In[137]:107
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:108
# └ @ Core .\In[137]:108
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:109
# └ @ Core .\In[137]:109
# This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.
# Another One!
# Angola 1988 has local donors!
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:12
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:16
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:20
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:27
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:30
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:37
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:37
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:78
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:78
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:112
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:112
# Another One!
# Angola 1991 has local donors!
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#975(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:118
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:118
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:41
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:41
# Another One!
# Angola 1996 has no local matches
# Another One!
# Albania 1990 has no local matches
# Another One!
# Argentina 1980 has local donors!
# Another One!
# Austria 2008 has local donors!
# Another One!
# Burundi 1994 has local donors!
# Another One!
# Belgium 2008 has local donors!
# Another One!
# Another One!
# Belarus 1999 has no local matches
# Another One!
# Brazil 1976 has local donors!
# Another One!
# Brazil 1990 has local donors!
# Another One!
# Brazil 1994 has local donors!
# Another One!
# Botswana 1984 has local donors!
# Another One!
# Central African Republic 1976 has local donors!
# Another One!
# Switzerland 2008 has local donors!
# Another One!
# Chile 1972 has local donors!
# Another One!
# China 1998 has local donors!
# Another One!
# Congo, Dem. Rep. 1991 has local donors!
# Another One!
# Congo, Dem. Rep. 1994 has no local matches
# Another One!
# Congo, Dem. Rep. 1999 has local donors!
# Another One!
# Congo, Rep. 1992 has local donors!
# Another One!
# Colombia 1982 has local donors!
# Another One!
# Colombia 1985 has local donors!
# Another One!
# Comoros 1994 has local donors!
# Another One!
# Cabo Verde 1993 has local donors!
# Another One!
# Czech Republic 1996 has no local matches
# Another One!
# Germany 2008 has local donors!
# Another One!
# Another One!
# Denmark 2008 has local donors!
# Another One!
# Ecuador 2008 has local donors!
# Another One!
# Egypt, Arab Rep. 1984 has local donors!
# Another One!
# Another One!
# Spain 1983 has local donors!
# Another One!
# Spain 2008 has local donors!
# Another One!
# Finland 1991 has local donors!
# Another One!
# Finland 1993 has local donors!
# Another One!
# Fiji 1998 has local donors!
# Another One!
# France 2008 has local donors!
# Another One!
# Gabon 2002 has no local matches
# Another One!
# United Kingdom 2007 has local donors!
# Another One!
# Georgia 1991 has no local matches
# Another One!
# Georgia 1999 has no local matches
# Another One!
# Ghana 1993 has local donors!
# Another One!
# Guinea 1993 has local donors!
# Another One!
# Guinea 2005 has local donors!
# Another One!
# Guinea-Bissau 1980 has no local matches
# Another One!
# Another One!
# Greece 1983 has local donors!
# Another One!
# Greece 2008 has local donors!
# Another One!
# Grenada 2004 has local donors!
# Another One!
# Guatemala 1986 has local donors!
# Another One!
# Guyana 1982 has no local matches
# Another One!
# Guyana 1987 has local donors!
# Another One!
# Another One!
# Haiti 2003 has local donors!
# Another One!
# Indonesia 1979 has local donors!
# Another One!
# India 1993 has local donors!
# Another One!
# Ireland 2008 has local donors!
# Another One!
# Iran, Islamic Rep. 1985 has no local matches
# Another One!
# Iran, Islamic Rep. 1992 has no local matches
# Another One!
# Iran, Islamic Rep. 2000 has local donors!
# Another One!
# Another One!
# Another One!
# Another One!
# Israel 1980 has local donors!
# Another One!
# Israel 1985 has local donors!
# Another One!
# Italy 1981 has local donors!
# Another One!
# Italy 2008 has local donors!
# Another One!
# Jamaica 1996 has local donors!
# Another One!
# Japan 1997 has local donors!
# Another One!
# Kazakhstan 2008 has local donors!
# Another One!
# Another One!
# Another One!
# Kuwait 1982 has no local matches
# Another One!
# Another One!
# Another One!
# Another One!
# Lao PDR 1997 has local donors!
# Another One!
# Another One!
# Another One!
# Liberia 1991 has no local matches
# Another One!
# Another One!
# Lesotho 1985 has local donors!
# Another One!
# Luxembourg 2008 has local donors!
# Another One!
# Moldova 2002 has no local matches
# Another One!
# Madagascar 1994 has local donors!
# Another One!
# Madagascar 2004 has local donors!
# Another One!
# Another One!
# Another One!
# Mali 1994 has local donors!
# Another One!
# Malta 1984 has local donors!
# Another One!
# Malta 1993 has local donors!
# Another One!
# Myanmar 1990 has local donors!
# Another One!
# Myanmar 1996 has local donors!
# Another One!
# Myanmar 2001 has local donors!
# Another One!
# Another One!
# Malaysia 1997 has local donors!
# Another One!
# Another One!
# Nigeria 1983 has no local matches
# Another One!
# Nigeria 1997 has local donors!
# Another One!
# Nigeria 2009 has no local matches
# Another One!
# Nicaragua 1985 has local donors!
# Another One!
# Nicaragua 2000 has local donors!
# Another One!
# Netherlands 2008 has local donors!
# Another One!
# Norway 1991 has local donors!
# Another One!
# New Zealand 1984 has local donors!
# Another One!
# Panama 1988 has no local matches
# Another One!
# Peru 1988 has no local matches
# Another One!
# Philippines 1997 has local donors!
# Another One!
# Another One!
# Portugal 2008 has local donors!
# Another One!
# Paraguay 1982 has no local matches
# Another One!
# Paraguay 1984 has local donors!
# Another One!
# Paraguay 1989 has local donors!
# Another One!
# Paraguay 1995 has local donors!
# Another One!
# Russian Federation 2008 has local donors!
# Another One!
# Sudan 1988 has no local matches
# Another One!
# Sudan 1994 has local donors!
# Another One!
# Sierra Leone 1989 has local donors!
# Another One!
# Sierra Leone 1998 has local donors!
# Another One!
# El Salvador 1986 has local donors!
# Another One!
# Another One!
# Another One!
# Another One!
# Suriname 1990 has no local matches
# Another One!
# Suriname 1995 has local donors!
# Another One!
# Suriname 2001 has local donors!
# Another One!
# Slovak Republic 1998 has local donors!
# Another One!
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:48
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:48
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:48
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:48
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:49
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:50
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:51
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:52
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at RunningPlacebosFunction.jl:53
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\RunningPlacebosFunction.jl:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:142
# └ @ Core In[137]:142
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:142
# └ @ Core In[137]:142
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:142
# └ @ Core In[137]:142
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:143
# └ @ Core In[137]:143
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:143
# └ @ Core In[137]:143
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:143
# └ @ Core In[137]:143
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:144
# └ @ Core In[137]:144
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:144
# └ @ Core In[137]:144
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:144
# └ @ Core In[137]:144
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:145
# └ @ Core In[137]:145
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:145
# └ @ Core In[137]:145
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:145
# └ @ Core In[137]:145
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:146
# └ @ Core In[137]:146
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:146
# └ @ Core In[137]:146
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:146
# └ @ Core In[137]:146
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:147
# └ @ Core In[137]:147
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:147
# └ @ Core In[137]:147
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:147
# └ @ Core In[137]:147
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:148
# └ @ Core In[137]:148
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at In[137]:155
# └ @ Core In[137]:155
# Albania 1997 has local donors!
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at In[137]:155
# └ @ Core In[137]:155
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at In[137]:158
# └ @ Core In[137]:158
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at In[137]:158
# └ @ Core In[137]:158
# Argentina 1975 has local donors!
# Argentina 1987 has local donors!
# Argentina 1989 has no local matches
# Argentina 1995 has local donors!
# Argentina 2001 has no local matches
# Benin 1988 has local donors!
# Burkina Faso 1990 has local donors!
# Bangladesh 1987 has local donors!
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local donors!
# Bolivia 1973 has no local matches
# Bolivia 1980 has local donors!
# Bolivia 1986 has local donors!
# Bolivia 1994 has local donors!
# Brazil 1982 has local donors!
# Brazil 1987 has local donors!
# Brazil 1992 has local donors!
# Central African Republic 1994 has local donors!
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local donors!
# Cote d'Ivoire 1994 has local donors!
# Cote d'Ivoire 2001 has local donors!
# Cameroon 1987 has local donors!
# Cameroon 1994 has local donors!
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local donors!
# Congo, Dem. Rep. 2009 has local donors!
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local donors!
# Colombia 1998 has local donors!
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local donors!
# Costa Rica 1991 has local donors!
# Costa Rica 1994 has local donors!
# Dominica 2002 has local donors!
# Dominican Republic 1982 has local donors!
# Dominican Republic 1985 has local donors!
# Dominican Republic 1990 has local donors!
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local donors!
# Algeria 1990 has local donors!
# Algeria 1994 has local donors!
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local donors!
# Spain 1977 has local donors!
# Gabon 1986 has no local matches
# Gabon 1994 has local donors!
# Ghana 1978 has no local matches
# Ghana 1982 has local donors!
# Ghana 2009 has local donors!
# Gambia, The 1985 has local donors!
# Guinea-Bissau 1994 has local donors!
# Guyana 1993 has local donors!
# Honduras 1981 has local donors!
# Honduras 1990 has local donors!
# Hungary 2008 has local donors!
# Indonesia 1997 has local donors!
# Iceland 2008 has no local matches
# Israel 1975 has local donors!
# Jamaica 1978 has no local matches
# Jamaica 1983 has local donors!
# Jamaica 1991 has local donors!
# Jamaica 2010 has local donors!
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local donors!
# Kenya 1985 has local donors!
# Kenya 1992 has local donors!
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local donors!
# Liberia 1980 has local donors!
# Sri Lanka 1978 has local donors!
# Latvia 2008 has local donors!
# Morocco 1980 has local donors!
# Morocco 1983 has local donors!
# Madagascar 1981 has no local matches
# Madagascar 1984 has local donors!
# Madagascar 1988 has local donors!
# Mexico 1977 has local donors!
# Mexico 1994 has local donors!
# Mali 1987 has no local matches
# Mongolia 1990 has local donors!
# Mongolia 1997 has local donors!
# Mongolia 2008 has local donors!
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local donors!
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local donors!
# Nepal 1992 has local donors!
# Pakistan 1972 has local donors!
# Panama 1983 has no local matches
# Peru 1976 has local donors!
# Peru 1978 has no local matches
# Peru 1981 has local donors!
# Peru 1983 has local donors!
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local donors!
# Paraguay 2002 has local donors!
# Romania 1996 has local donors!
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local donors!
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local donors!
# Senegal 1994 has local donors!
# Sierra Leone 1977 has local donors!
# Sierra Leone 1983 has local donors!
# El Salvador 1989 has local donors!
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local donors!
# Togo 1993 has local donors!
# Thailand 1997 has local donors!
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local donors!
# Turkey 1984 has local donors!
# Turkey 2000 has local donors!
# Uganda 1988 has local donors!
# Uganda 1994 has local donors!
# Ukraine 1998 has no local matches
# Ukraine 2008 has local donors!
# Uruguay 1972 has local donors!
# Uruguay 1981 has local donors!
# Uruguay 1983 has no local matches
# Uruguay 1990 has local donors!
# Uruguay 2002 has no local matches
# Uzbekistan 1994 has local donors!
# Venezuela, RB 1989 has local donors!
# Zambia 1983 has no local matches
# Zambia 1995 has local donors!
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local donors!
# Zimbabwe 1998 has local donors!
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at In[137]:171
# └ @ Core In[137]:171
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:179
# └ @ Core In[137]:179
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:180
# └ @ Core In[137]:180
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:190
# └ @ Core In[137]:190
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:208
# └ @ Core .\In[137]:208
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:221
# └ @ Core In[137]:221
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:221
# └ @ Core In[137]:221
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:221
# └ @ Core In[137]:221
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:221
# └ @ Core In[137]:221
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:223
# └ @ Core In[137]:223
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:223
# └ @ Core In[137]:223
# The number of treated observations with synthetic controls is 99
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at In[137]:232
# └ @ Core In[137]:232
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at In[137]:232
# └ @ Core In[137]:232
# ┌ Warning: `getindex(df::DataFrame, col_inds::Union{AbstractVector, Regex, Not})` is deprecated, use `df[:, col_inds]` instead.
# │   caller = top-level scope at In[137]:238
# └ @ Core In[137]:238
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = top-level scope at In[137]:238
# └ @ Core In[137]:238
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:250
# └ @ Core In[137]:250
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:250
# └ @ Core In[137]:250
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:251
# └ @ Core In[137]:251
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:251
# └ @ Core In[137]:251
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:251
# └ @ Core In[137]:251
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:252
# └ @ Core In[137]:252
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:252
# └ @ Core In[137]:252
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:252
# └ @ Core In[137]:252
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:252
# └ @ Core In[137]:252
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:253
# └ @ Core In[137]:253
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:253
# └ @ Core In[137]:253
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:253
# └ @ Core In[137]:253
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:253
# └ @ Core In[137]:253
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:253
# └ @ Core In[137]:253
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:254
# └ @ Core In[137]:254
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:255
# └ @ Core In[137]:255
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:257
# └ @ Core In[137]:257
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:257
# └ @ Core In[137]:257
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:259
# └ @ Core In[137]:259
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:259
# └ @ Core In[137]:259
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:259
# └ @ Core In[137]:259
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:260
# └ @ Core In[137]:260
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:260
# └ @ Core In[137]:260
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:260
# └ @ Core In[137]:260
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:261
# └ @ Core In[137]:261
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:261
# └ @ Core In[137]:261
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:261
# └ @ Core In[137]:261
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:262
# └ @ Core In[137]:262
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:262
# └ @ Core In[137]:262
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:262
# └ @ Core In[137]:262
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:263
# └ @ Core In[137]:263
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:263
# └ @ Core In[137]:263
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:263
# └ @ Core In[137]:263
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:264
# └ @ Core In[137]:264
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:264
# └ @ Core In[137]:264
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:264
# └ @ Core In[137]:264
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:269
# └ @ Core .\In[137]:269
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:288
# └ @ Core In[137]:288
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:290
# └ @ Core In[137]:290
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:291
# └ @ Core In[137]:291
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# Average Cumulative Effect is 11.74307756772424
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[137]:294
# └ @ Core In[137]:294
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[137]:297
# └ @ Core In[137]:297
# ArgumentError: invalid index: :WGI of type Symbol
#
# Stacktrace:
#  [1] to_index(::Symbol) at .\indices.jl:273
#  [2] to_index(::BitArray{1}, ::Symbol) at .\indices.jl:250
#  [3] to_indices at .\indices.jl:301 [inlined]
#  [4] to_indices at .\indices.jl:298 [inlined]
#  [5] getindex(::BitArray{1}, ::Symbol) at .\abstractarray.jl:981
#  [6] HeterogeneityScatter(::Symbol) at .\In[55]:4
#  [7] top-level scope at In[137]:299

# %%
using StatsPlots
	s = :conditions
	Temp = dropmissing(TreatedMatched[:, [:Country, :year, s, :CumulativeEffect]])
	x 	= convert(Array, Temp[s])
	y 	= convert(Array, Temp[:CumulativeEffect])
	(b,v) = Regress(y,x)
	yhat = b[1]ones(size(x)[1]) + b[2]*x
	ss = string(s)
	scatter(Temp[s], Temp[:CumulativeEffect], label="", ylabel="Estimated Cumulative Effect", xlabel="Conditionality Index", markersize=[1], marker=:x)
	plot!(x, yhat, label="", linecolor=:black, linewidth=[2])
	#savefig(joinpath(output_directory, "Heterogeneity_$ss.pdf"))
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[136]:4
# └ @ Core In[136]:4
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[136]:5
# └ @ Core In[136]:5
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[136]:9
# └ @ Core In[136]:9
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[136]:9
# └ @ Core In[136]:9

# %%
function HeterogeneityScatter(s::Symbol)
	Temp = dropmissing(TreatedMatched[:, [:Country, :year, s, :CumulativeEffect]])
	x 	= convert(Array, Temp[s])
	y 	= convert(Array, Temp[:CumulativeEffect])
	(b,v) = Regress(y,x)
	yhat = b[1]ones(size(x)[1]) + b[2]*x
	ss = string(s)
	scatter(Temp[s], Temp[:CumulativeEffect], label="", ylabel="Estimated Cumulative Effect", xlabel="Conditionality Index", markersize=[1], marker=:x)
	plot!(x, yhat, label="", linecolor=:black, linewidth=[2])
	savefig(joinpath(output_directory, "Heterogeneity_$ss.pdf"))
end
#HeterogeneityScatter(:WGI)
s = :WGI
	Temp = dropmissing(TreatedMatched[:, [:Country, :year, s, :CumulativeEffect]])
	x 	= convert(Array, Temp[s])
	y 	= convert(Array, Temp[:CumulativeEffect])
	(b,v) = Regress(y,x)
b[2]/sqrt(v[2,2])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[162]:15
# └ @ Core In[162]:15
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[162]:16
# └ @ Core In[162]:16
# -0.9804634687308523

# %%
include("GenSynthetics_NLopt.jl")
W 		= ones(10,1)  #diaganol of weighting matrix (equal weights in baseline)
matchon = [:LGrowth5, :LGrowth4, :LGrowth3, :LGrowth2, :LGrowth1, :DWDI, :Banking, :Currency, :Debt]
predict = [:FGrowth1, :FGrowth2, :FGrowth3, :FGrowth4, :FGrowth5, :FGrowth6]
matchtol= Inf	  ### For if I want to throw away bad matches 
bounds  = [7, 7, 7, 7, 7, 7, .5, .5, .5]
(TreatedMatched, Synthetics, DonorWeights) = GenSynthetics(IMFCrises, NoIMFCrises, matchon, predict, localtol=bounds, matchweights=W)
# Out:
# Albania 1997 has local donors!
# Argentina 1975 has local donors!
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:78
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:78
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:112
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:112
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#36(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:118
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:118
# Argentina 1987 has local donors!
# Argentina 1989 has no local matches
# Argentina 1995 has local donors!
# Argentina 2001 has no local matches
# Benin 1988 has local donors!
# Burkina Faso 1990 has local donors!
# Bangladesh 1987 has local donors!
# Bulgaria 1990 has no local matches
# Bulgaria 1996 has no local matches
# Belarus 2009 has local donors!
# Bolivia 1973 has no local matches
# Bolivia 1980 has local donors!
# Bolivia 1986 has local donors!
# Bolivia 1994 has local donors!
# Brazil 1982 has local donors!
# Brazil 1987 has local donors!
# Brazil 1992 has local donors!
# Central African Republic 1994 has local donors!
# Cote d'Ivoire 1984 has no local matches
# Cote d'Ivoire 1988 has local donors!
# Cote d'Ivoire 1994 has local donors!
# Cote d'Ivoire 2001 has local donors!
# Cameroon 1987 has local donors!
# Cameroon 1994 has local donors!
# Congo, Dem. Rep. 1976 has no local matches
# Congo, Dem. Rep. 1983 has no local matches
# Congo, Dem. Rep. 1989 has local donors!
# Congo, Dem. Rep. 2009 has local donors!
# Congo, Rep. 1986 has no local matches
# Congo, Rep. 1994 has local donors!
# Colombia 1998 has local donors!
# Costa Rica 1981 has no local matches
# Costa Rica 1987 has local donors!
# Costa Rica 1991 has local donors!
# Costa Rica 1994 has local donors!
# Dominica 2002 has local donors!
# Dominican Republic 1982 has local donors!
# Dominican Republic 1985 has local donors!
# Dominican Republic 1990 has local donors!
# Dominican Republic 2003 has no local matches
# Algeria 1988 has local donors!
# Algeria 1990 has local donors!
# Algeria 1994 has local donors!
# Ecuador 1982 has no local matches
# Egypt, Arab Rep. 1990 has local donors!
# Spain 1977 has local donors!
# Gabon 1986 has no local matches
# Gabon 1994 has local donors!
# Ghana 1978 has no local matches
# Ghana 1982 has local donors!
# Ghana 2009 has local donors!
# Gambia, The 1985 has local donors!
# Guinea-Bissau 1994 has local donors!
# Guyana 1993 has local donors!
# Honduras 1981 has local donors!
# Honduras 1990 has local donors!
# Hungary 2008 has local donors!
# Indonesia 1997 has local donors!
# Iceland 2008 has no local matches
# Israel 1975 has local donors!
# Jamaica 1978 has no local matches
# Jamaica 1983 has local donors!
# Jamaica 1991 has local donors!
# Jamaica 2010 has local donors!
# Jordan 1989 has no local matches
# Kazakhstan 1999 has local donors!
# Kenya 1985 has local donors!
# Kenya 1992 has local donors!
# Kyrgyz Republic 1997 has no local matches
# Korea, Rep. 1997 has local donors!
# Liberia 1980 has local donors!
# Sri Lanka 1978 has local donors!
# Latvia 2008 has local donors!
# Morocco 1980 has local donors!
# Morocco 1983 has local donors!
# Madagascar 1981 has no local matches
# Madagascar 1984 has local donors!
# Madagascar 1988 has local donors!
# Mexico 1977 has local donors!
# Mexico 1994 has local donors!
# Mali 1987 has no local matches
# Mongolia 1990 has local donors!
# Mongolia 1997 has local donors!
# Mongolia 2008 has local donors!
# Mozambique 1987 has no local matches
# Malawi 1982 has no local matches
# Malawi 1994 has no local matches
# Niger 1983 has no local matches
# Niger 1994 has local donors!
# Nigeria 1989 has no local matches
# Nigeria 1991 has no local matches
# Nicaragua 1979 has no local matches
# Nicaragua 1990 has no local matches
# Nepal 1984 has local donors!
# Nepal 1992 has local donors!
# Pakistan 1972 has local donors!
# Panama 1983 has no local matches
# Peru 1976 has local donors!
# Peru 1978 has no local matches
# Peru 1981 has local donors!
# Peru 1983 has local donors!
# Philippines 1983 has no local matches
# Papua New Guinea 1995 has no local matches
# Portugal 1983 has local donors!
# Paraguay 2002 has local donors!
# Romania 1996 has local donors!
# Russian Federation 1998 has no local matches
# Rwanda 1991 has local donors!
# Sudan 1979 has no local matches
# Sudan 1981 has no local matches
# Senegal 1981 has no local matches
# Senegal 1988 has local donors!
# Senegal 1994 has local donors!
# Sierra Leone 1977 has local donors!
# Sierra Leone 1983 has local donors!
# El Salvador 1989 has local donors!
# Seychelles 2008 has no local matches
# Chad 1994 has no local matches
# Togo 1979 has local donors!
# Togo 1993 has local donors!
# Thailand 1997 has local donors!
# Trinidad and Tobago 1989 has no local matches
# Turkey 1978 has no local matches
# Turkey 1982 has local donors!
# Turkey 1984 has local donors!
# Turkey 2000 has local donors!
# Uganda 1988 has local donors!
# Uganda 1994 has local donors!
# Ukraine 1998 has no local matches
# Ukraine 2008 has local donors!
# Uruguay 1972 has local donors!
# Uruguay 1981 has local donors!
# Uruguay 1983 has no local matches
# Uruguay 1990 has local donors!
# Uruguay 2002 has no local matches
# Uzbekistan 1994 has local donors!
# Venezuela, RB 1989 has local donors!
# Zambia 1983 has no local matches
# Zambia 1995 has local donors!
# Zimbabwe 1983 has no local matches
# Zimbabwe 1991 has local donors!
# Zimbabwe 1998 has local donors!
# (99×33 DataFrame. Omitted printing of 27 columns
# │ Row │ Country       │ year  │ CAB       │ Infl      │ EXDEBT   │ rgdpe     │
# │     │ String        │ Int64 │ Float64⍰  │ Float64⍰  │ Float64⍰ │ Float64⍰  │
# ├─────┼───────────────┼───────┼───────────┼───────────┼──────────┼───────────┤
# │ 1   │ Albania       │ 1997  │ -12.0536  │ 33.1803   │ 22.3751  │ 12886.2   │
# │ 2   │ Argentina     │ 1975  │ missing   │ missing   │ missing  │ 1.11644e5 │
# │ 3   │ Argentina     │ 1987  │ -3.81167  │ missing   │ missing  │ 1.75065e5 │
# │ 4   │ Argentina     │ 1995  │ -1.98346  │ missing   │ missing  │ 4.19159e5 │
# │ 5   │ Benin         │ 1988  │ -6.51092  │ missing   │ 73.3466  │ 6218.21   │
# │ 6   │ Burkina Faso  │ 1990  │ missing   │ -0.504303 │ 26.9452  │ 8036.22   │
# │ 7   │ Bangladesh    │ 1987  │ -0.975865 │ 9.8747    │ 39.1603  │ 1.17936e5 │
# │ 8   │ Belarus       │ 2009  │ -12.0545  │ 12.9457   │ 44.37    │ 134128.0  │
# │ 9   │ Bolivia       │ 1980  │ -0.141377 │ 47.2417   │ 65.3094  │ 11840.1   │
# │ 10  │ Bolivia       │ 1986  │ -9.81884  │ 276.336   │ 155.35   │ 13687.8   │
# ⋮
# │ 89  │ Uganda        │ 1988  │ -2.99911  │ missing   │ 30.0803  │ 13263.5   │
# │ 90  │ Uganda        │ 1994  │ -4.36544  │ 10.0368   │ 86.4667  │ 20826.5   │
# │ 91  │ Ukraine       │ 2008  │ -7.10779  │ 25.2265   │ 55.8248  │ 4.47102e5 │
# │ 92  │ Uruguay       │ 1972  │ missing   │ 76.4849   │ missing  │ 21561.6   │
# │ 93  │ Uruguay       │ 1981  │ -4.17619  │ 34.0453   │ missing  │ 28288.7   │
# │ 94  │ Uruguay       │ 1990  │ 1.99907   │ 112.526   │ missing  │ 27874.7   │
# │ 95  │ Uzbekistan    │ 1994  │ missing   │ missing   │ 9.7011   │ 85906.9   │
# │ 96  │ Venezuela, RB │ 1989  │ 4.96482   │ missing   │ 78.672   │ 1.5344e5  │
# │ 97  │ Zambia        │ 1995  │ missing   │ 34.9296   │ 195.167  │ 9223.97   │
# │ 98  │ Zimbabwe      │ 1991  │ -5.28175  │ missing   │ 42.169   │ 52277.5   │
# │ 99  │ Zimbabwe      │ 1998  │ missing   │ missing   │ 77.7912  │ 45291.7   │, 99×18 DataFrame. Omitted printing of 13 columns
# │ Row │ Country                 │ year  │ LGrowth5   │ LGrowth4 │ LGrowth3   │
# │     │ String                  │ Int64 │ Float64⍰   │ Float64⍰ │ Float64⍰   │
# ├─────┼─────────────────────────┼───────┼────────────┼──────────┼────────────┤
# │ 1   │ Synthetic Albania       │ 1997  │ -10.4081   │ 3.60829  │ 2.06113    │
# │ 2   │ Synthetic Argentina     │ 1975  │ 3.10254    │ 5.18624  │ 2.13091    │
# │ 3   │ Synthetic Argentina     │ 1987  │ -0.0615657 │ 3.57821  │ 2.57268    │
# │ 4   │ Synthetic Argentina     │ 1995  │ 2.89114    │ 6.59205  │ 5.97585    │
# │ 5   │ Synthetic Benin         │ 1988  │ 0.366176   │ 2.34018  │ 2.67225    │
# │ 6   │ Synthetic Burkina Faso  │ 1990  │ 7.30927    │ 5.70244  │ 1.47408    │
# │ 7   │ Synthetic Bangladesh    │ 1987  │ 2.20306    │ 3.83658  │ 4.73031    │
# │ 8   │ Synthetic Belarus       │ 2009  │ 8.41424    │ 8.17911  │ 6.29139    │
# │ 9   │ Synthetic Bolivia       │ 1980  │ 6.27078    │ 2.3469   │ 0.764355   │
# │ 10  │ Synthetic Bolivia       │ 1986  │ 2.25926    │ 0.64687  │ 0.802427   │
# ⋮
# │ 89  │ Synthetic Uganda        │ 1988  │ 3.85438    │ 2.65403  │ 0.88584    │
# │ 90  │ Synthetic Uganda        │ 1994  │ 6.60962    │ 6.18105  │ 5.17972    │
# │ 91  │ Synthetic Ukraine       │ 2008  │ 7.19952    │ 8.40574  │ 6.5027     │
# │ 92  │ Synthetic Uruguay       │ 1972  │ -0.195272  │ 2.20885  │ 4.76545    │
# │ 93  │ Synthetic Uruguay       │ 1981  │ 3.33214    │ 2.97731  │ 5.0081     │
# │ 94  │ Synthetic Uruguay       │ 1990  │ 1.6222     │ 6.0981   │ 6.0967     │
# │ 95  │ Synthetic Uzbekistan    │ 1994  │ 1.41771    │ 3.26124  │ -0.0314392 │
# │ 96  │ Synthetic Venezuela, RB │ 1989  │ 2.55904    │ 2.65481  │ 0.754675   │
# │ 97  │ Synthetic Zambia        │ 1995  │ 1.3495     │ 3.49982  │ 4.99684    │
# │ 98  │ Synthetic Zimbabwe      │ 1991  │ 2.64865    │ 1.81602  │ 6.1403     │
# │ 99  │ Synthetic Zimbabwe      │ 1998  │ 1.50559    │ 7.90001  │ 3.23031    │, 132×102 DataFrame. Omitted printing of 96 columns
# │ Row │ Country       │ year   │ ID     │ weight   │ weight_1    │ weight_2 │
# │     │ String⍰       │ Int64⍰ │ Int64⍰ │ Float64⍰ │ Float64⍰    │ Float64⍰ │
# ├─────┼───────────────┼────────┼────────┼──────────┼─────────────┼──────────┤
# │ 1   │ Angola        │ 1988   │ 1      │ 0.0      │ 0.0         │ 0.0      │
# │ 2   │ Angola        │ 1991   │ 2      │ 0.0      │ 0.0         │ 0.0      │
# │ 3   │ Angola        │ 1996   │ 3      │ 0.0      │ 0.0         │ 0.0      │
# │ 4   │ Albania       │ 1990   │ 4      │ 0.0      │ 0.0         │ 0.0      │
# │ 5   │ Argentina     │ 1980   │ 5      │ 0.0      │ 0.0         │ 0.0      │
# │ 6   │ Austria       │ 2008   │ 6      │ 0.0      │ 0.0         │ 0.0      │
# │ 7   │ Burundi       │ 1994   │ 7      │ 0.0      │ 0.0         │ 0.0      │
# │ 8   │ Belgium       │ 2008   │ 8      │ 0.0      │ 0.0         │ 0.0      │
# │ 9   │ Belarus       │ 1999   │ 9      │ 0.0      │ 0.0         │ 0.0      │
# │ 10  │ Brazil        │ 1976   │ 10     │ 0.0      │ 0.0         │ 0.0      │
# ⋮
# │ 122 │ United States │ 2007   │ 122    │ 0.0      │ 0.0         │ 0.0      │
# │ 123 │ Uzbekistan    │ 2000   │ 123    │ 0.0      │ 1.95828e-20 │ 0.0      │
# │ 124 │ Venezuela, RB │ 1982   │ 124    │ 0.0      │ 0.0         │ 0.0      │
# │ 125 │ Venezuela, RB │ 1984   │ 125    │ 0.0      │ 0.0         │ 0.0      │
# │ 126 │ Venezuela, RB │ 1994   │ 126    │ 0.0      │ 0.0         │ 0.0      │
# │ 127 │ Venezuela, RB │ 2002   │ 127    │ 0.0      │ 0.0         │ 0.0      │
# │ 128 │ Vietnam       │ 1997   │ 128    │ 0.0      │ 0.0         │ 0.0      │
# │ 129 │ South Africa  │ 1984   │ 129    │ 0.0      │ 0.0         │ 0.0      │
# │ 130 │ Zambia        │ 1989   │ 130    │ 0.0      │ 0.306372    │ 0.0      │
# │ 131 │ Zimbabwe      │ 1995   │ 131    │ 0.0      │ 0.0         │ 0.0      │
# │ 132 │ Zimbabwe      │ 2003   │ 132    │ 0.0      │ 0.0         │ 0.0      │)

# %%
BankingOutcomes = TreatedMatched[TreatedMatched[:, :Banking].==1, [:Country, :year]]
BankingOutcomes = join(BankingOutcomes, MainDiffDataFrame, on=[:Country, :year], kind=:inner)
CurrencyOutcomes = TreatedMatched[TreatedMatched[:, :Currency].==1, [:Country, :year]]
CurrencyOutcomes = join(CurrencyOutcomes, MainDiffDataFrame, on=[:Country, :year], kind=:inner)
DebtOutcomes = TreatedMatched[TreatedMatched[:, :Debt].==1, [:Country, :year]]
DebtOutcomes = join(DebtOutcomes, MainDiffDataFrame, on=[:Country, :year], kind=:inner)

Averages = zeros(3)
Outcomes = (BankingOutcomes, CurrencyOutcomes, DebtOutcomes)
for (i, c) in enumerate(Outcomes)
	c[:CumulativeEffect] = map((x1,x2,x3,x4,x5, x6) -> +(x1, x2, x3, x4, x5, x6), c[:LevelDiff1], c[:LevelDiff2], c[:LevelDiff3], c[:LevelDiff4], c[:LevelDiff5], c[:LevelDiff6])
	Averages[i] = mean(c[:CumulativeEffect])
end
Averages
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = top-level scope at In[26]:11
# └ @ Core In[26]:11
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[26]:12
# └ @ Core In[26]:12
# 3-element Array{Float64,1}:
#  20.776443787473507
#   5.316213489693554
#  23.545030230936124

# %%
##This function runs the synthetic control function and creates 

using CSV 
using DataFrames

include("GenSynthetics_NLopt.jl")

function RunningPlacebos(matchon, W, bounds, predict, Pool::DataFrame)

    N = size(Pool)[1]
    i = collect(1:1:N)
    Pool[:i] = .5*2*i

    ###Before Running want to ensure Pooled group has no missings for necessary values
    bigp = size(Pool)[1]
    Pool[:ID] = collect(1:1:bigp)
    completecheck = [:ID; matchon; predict]
    tempPool = Pool[:, completecheck]
    tempPool = tempPool[completecases(tempPool),:]
    PoolCompleteID = DataFrame(ID = tempPool[:ID])
    Pool = join(Pool, PoolCompleteID, on=:ID, kind=:inner)
    relevant = [:Country; :year; matchon; predict]
    SynthRelevant = Pool[:, relevant]

    ##Now making two empty DataFrames to populate with results as I go
    SyntheticPlacebos = SynthRelevant[1:1, :]
    SyntheticPlacebos[:SqError] = [2.]
    SyntheticPlacebos = deleterows!(SyntheticPlacebos,1)
    TreatPlaceb = SyntheticPlacebos[SyntheticPlacebos[:LGrowth5].<Inf,:]  #arbitrary to just copy it
    TreatPlaceb[:ID] = []
    global SyntheticPlacebos
    global TreatPlaceb

    #Loops over and runs the Synthetic Controls for each placebo against all others given specification
    for j = 1:size(Pool)[1]
        println("Another One!")
        placebo = Pool[Pool[:i].==j, relevant] 
        if size(placebo)[1]>0
            dropplaceb = Pool[Pool[:i].!=j, relevant]
            (Placebt, Placebj, w) = GenSynthetics(placebo, dropplaceb, matchon, predict, localtol= bounds, matchweights=W)
            Placebt[:SqError]=0.
            SyntheticPlacebos=[SyntheticPlacebos; Placebj]
            TreatPlaceb = [TreatPlaceb; Placebt]
        end
    end

    for z = (SyntheticPlacebos, TreatPlaceb)
        z[:PostGrowth1] = map((x1) -> 100*(1+x1/100 -1), z[:FGrowth1])
        z[:PostGrowth2] = map((x1,x2) -> 100*((1+x1/100)*(1+x2/100) -1), z[:FGrowth1], z[:FGrowth2])
        z[:PostGrowth3] = map((x1,x2,x3) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3])
        z[:PostGrowth4] = map((x1,x2,x3,x4) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4])
        z[:PostGrowth5] = map((x1,x2,x3,x4,x5) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100)*(1+x5/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4], z[:FGrowth5])
        z[:PostGrowth6] = map((x1,x2,x3,x4,x5, x6) -> 100*((1+x1/100)*(1+x2/100)*(1+x3/100)*(1+x4/100)*(1+x5/100)*(1+x6/100) -1), z[:FGrowth1], z[:FGrowth2], z[:FGrowth3], z[:FGrowth4], z[:FGrowth5], z[:FGrowth6])
    end
return TreatPlaceb, SyntheticPlacebos
end

println("This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.")
# Out:
# This function takes: matching variables, weights on these matches, outcomes to predict, and Pool DataFrame as arguments and returns two DataFrames: placebos that have matches and then their synthetic controls.

# %%
RunningPlacebos(matchon, W, bounds, predict, NoIMFCrises)
# Out:
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:12
# └ @ Main .\In[16]:12
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:16
# └ @ Main .\In[16]:16
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:20
# └ @ Main .\In[16]:20
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:27
# └ @ Main .\In[16]:27
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:29
# └ @ Main .\In[16]:29
# Another One!
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:30
# └ @ Main .\In[16]:30
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:37
# └ @ Main .\In[16]:37
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:39
# └ @ Main .\In[16]:39
# Angola 1988 has local donors!
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:21
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:21
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:22
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:22
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:28
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:28
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:29
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:29
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:39
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:39
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:40
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:40
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:43
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:43
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:68
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:68
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:71
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:71
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:78
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:78
# ┌ Warning: `convert(::Type{Array}, df::AbstractDataFrame)` is deprecated, use `convert(Matrix, df)` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:112
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:112
# ┌ Warning: `convert(::Type{Array}, dfr::DataFrameRow)` is deprecated, use `permutedims(Vector(dfr))` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:116
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:116
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = #GenSynthetics#43(::Float64, ::Array{Float64,1}, ::Array{Float64,2}, ::typeof(GenSynthetics), ::DataFrame, ::DataFrame, ::Array{Symbol,1}, ::Array{Symbol,1}) at GenSynthetics_NLopt.jl:118
# └ @ Main C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\GenSynthetics_NLopt.jl:118
# ┌ Warning: Implicit broadcasting to a new column in DataFrame assignment is deprecated.Use `df[!, col_ind] .= v`  when `df` has some columns
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:41
# └ @ Main .\In[16]:41
# Another One!
# Angola 1991 has local donors!
# Another One!
# Angola 1996 has no local matches
# Another One!
# Albania 1990 has no local matches
# Another One!
# Argentina 1980 has local donors!
# Another One!
# Austria 2008 has local donors!
# Another One!
# Burundi 1994 has local donors!
# Another One!
# Belgium 2008 has local donors!
# Another One!
# Another One!
# Belarus 1999 has no local matches
# Another One!
# Brazil 1976 has local donors!
# Another One!
# Brazil 1990 has local donors!
# Another One!
# Brazil 1994 has local donors!
# Another One!
# Botswana 1984 has local donors!
# Another One!
# Central African Republic 1976 has local donors!
# Another One!
# Switzerland 2008 has local donors!
# Another One!
# Chile 1972 has local donors!
# Another One!
# China 1998 has local donors!
# Another One!
# Congo, Dem. Rep. 1991 has local donors!
# Another One!
# Congo, Dem. Rep. 1994 has no local matches
# Another One!
# Congo, Dem. Rep. 1999 has local donors!
# Another One!
# Congo, Rep. 1992 has local donors!
# Another One!
# Colombia 1982 has local donors!
# Another One!
# Colombia 1985 has local donors!
# Another One!
# Comoros 1994 has local donors!
# Another One!
# Cabo Verde 1993 has local donors!
# Another One!
# Czech Republic 1996 has no local matches
# Another One!
# Germany 2008 has local donors!
# Another One!
# Another One!
# Denmark 2008 has local donors!
# Another One!
# Ecuador 2008 has local donors!
# Another One!
# Egypt, Arab Rep. 1984 has local donors!
# Another One!
# Another One!
# Spain 1983 has local donors!
# Another One!
# Spain 2008 has local donors!
# Another One!
# Finland 1991 has local donors!
# Another One!
# Finland 1993 has local donors!
# Another One!
# Fiji 1998 has local donors!
# Another One!
# France 2008 has local donors!
# Another One!
# Gabon 2002 has no local matches
# Another One!
# United Kingdom 2007 has local donors!
# Another One!
# Georgia 1991 has no local matches
# Another One!
# Georgia 1999 has no local matches
# Another One!
# Ghana 1993 has local donors!
# Another One!
# Guinea 1993 has local donors!
# Another One!
# Guinea 2005 has local donors!
# Another One!
# Guinea-Bissau 1980 has no local matches
# Another One!
# Another One!
# Greece 1983 has local donors!
# Another One!
# Greece 2008 has local donors!
# Another One!
# Grenada 2004 has local donors!
# Another One!
# Guatemala 1986 has local donors!
# Another One!
# Guyana 1982 has no local matches
# Another One!
# Guyana 1987 has local donors!
# Another One!
# Another One!
# Haiti 2003 has local donors!
# Another One!
# Indonesia 1979 has local donors!
# Another One!
# India 1993 has local donors!
# Another One!
# Ireland 2008 has local donors!
# Another One!
# Iran, Islamic Rep. 1985 has no local matches
# Another One!
# Iran, Islamic Rep. 1992 has no local matches
# Another One!
# Iran, Islamic Rep. 2000 has local donors!
# Another One!
# Another One!
# Another One!
# Another One!
# Israel 1980 has local donors!
# Another One!
# Israel 1985 has local donors!
# Another One!
# Italy 1981 has local donors!
# Another One!
# Italy 2008 has local donors!
# Another One!
# Jamaica 1996 has local donors!
# Another One!
# Japan 1997 has local donors!
# Another One!
# Kazakhstan 2008 has local donors!
# Another One!
# Another One!
# Another One!
# Kuwait 1982 has no local matches
# Another One!
# Another One!
# Another One!
# Another One!
# Lao PDR 1997 has local donors!
# Another One!
# Another One!
# Another One!
# Liberia 1991 has no local matches
# Another One!
# Another One!
# Lesotho 1985 has local donors!
# Another One!
# Luxembourg 2008 has local donors!
# Another One!
# Moldova 2002 has no local matches
# Another One!
# Madagascar 1994 has local donors!
# Another One!
# Madagascar 2004 has local donors!
# Another One!
# Another One!
# Another One!
# Mali 1994 has local donors!
# Another One!
# Malta 1984 has local donors!
# Another One!
# Malta 1993 has local donors!
# Another One!
# Myanmar 1990 has local donors!
# Another One!
# Myanmar 1996 has local donors!
# Another One!
# Myanmar 2001 has local donors!
# Another One!
# Another One!
# Malaysia 1997 has local donors!
# Another One!
# Another One!
# Nigeria 1983 has no local matches
# Another One!
# Nigeria 1997 has local donors!
# Another One!
# Nigeria 2009 has no local matches
# Another One!
# Nicaragua 1985 has local donors!
# Another One!
# Nicaragua 2000 has local donors!
# Another One!
# Netherlands 2008 has local donors!
# Another One!
# Norway 1991 has local donors!
# Another One!
# New Zealand 1984 has local donors!
# Another One!
# Panama 1988 has no local matches
# Another One!
# Peru 1988 has no local matches
# Another One!
# Philippines 1997 has local donors!
# Another One!
# Another One!
# Portugal 2008 has local donors!
# Another One!
# Paraguay 1982 has no local matches
# Another One!
# Paraguay 1984 has local donors!
# Another One!
# Paraguay 1989 has local donors!
# Another One!
# Paraguay 1995 has local donors!
# Another One!
# Russian Federation 2008 has local donors!
# Another One!
# Sudan 1988 has no local matches
# Another One!
# Sudan 1994 has local donors!
# Another One!
# Sierra Leone 1989 has local donors!
# Another One!
# Sierra Leone 1998 has local donors!
# Another One!
# El Salvador 1986 has local donors!
# Another One!
# Another One!
# Another One!
# Another One!
# Suriname 1990 has no local matches
# Another One!
# Suriname 1995 has local donors!
# Another One!
# Suriname 2001 has local donors!
# Another One!
# Slovak Republic 1998 has local donors!
# Another One!
# Another One!
# Slovenia 2008 has local donors!
# Another One!
# Sweden 1991 has local donors!
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:48
# └ @ Main .\In[16]:48
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:48
# └ @ Main .\In[16]:48
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:49
# └ @ Main .\In[16]:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:49
# └ @ Main .\In[16]:49
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:49
# └ @ Main .\In[16]:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:50
# └ @ Main .\In[16]:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:50
# └ @ Main .\In[16]:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:50
# └ @ Main .\In[16]:50
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:50
# └ @ Main .\In[16]:50
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:51
# └ @ Main .\In[16]:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:51
# └ @ Main .\In[16]:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:51
# └ @ Main .\In[16]:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:51
# └ @ Main .\In[16]:51
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:51
# └ @ Main .\In[16]:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:52
# └ @ Main .\In[16]:52
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# ┌ Warning: `setindex!(df::DataFrame, v::AbstractVector, col_ind::ColumnIndex)` is deprecated, use `begin
# │     df[!, col_ind] = v
# │     df
# │ end` instead.
# │   caller = RunningPlacebos(::Array{Symbol,1}, ::Array{Float64,2}, ::Array{Float64,1}, ::Array{Symbol,1}, ::DataFrame) at In[16]:53
# └ @ Main .\In[16]:53
# (85×25 DataFrame. Omitted printing of 20 columns
# │ Row │ Country            │ year  │ LGrowth5   │ LGrowth4 │ LGrowth3  │
# │     │ String             │ Int64 │ Float64⍰   │ Float64⍰ │ Float64⍰  │
# ├─────┼────────────────────┼───────┼────────────┼──────────┼───────────┤
# │ 1   │ Angola             │ 1988  │ 4.2        │ 6.0      │ 3.5       │
# │ 2   │ Angola             │ 1991  │ 2.9        │ 4.08275  │ 6.12889   │
# │ 3   │ Argentina          │ 1980  │ -0.0284121 │ -2.01825 │ 6.93415   │
# │ 4   │ Austria            │ 2008  │ 0.941473   │ 2.73512  │ 2.24407   │
# │ 5   │ Burundi            │ 1994  │ 1.3495     │ 3.49982  │ 4.99684   │
# │ 6   │ Belgium            │ 2008  │ 0.774567   │ 3.63468  │ 2.09427   │
# │ 7   │ Brazil             │ 1976  │ 11.2951    │ 12.0528  │ 13.9787   │
# │ 8   │ Brazil             │ 1990  │ 7.94586    │ 7.9883   │ 3.59963   │
# │ 9   │ Brazil             │ 1994  │ 3.27946    │ -3.10236 │ 1.51194   │
# │ 10  │ Botswana           │ 1984  │ 12.1486    │ 11.9869  │ 9.06486   │
# ⋮
# │ 75  │ Paraguay           │ 1995  │ 4.12328    │ 3.49365  │ 1.69643   │
# │ 76  │ Russian Federation │ 2008  │ 7.29585    │ 7.17595  │ 6.37619   │
# │ 77  │ Sudan              │ 1994  │ 8.93139    │ -5.47005 │ 7.51091   │
# │ 78  │ Sierra Leone       │ 1989  │ 4.09303    │ -5.31134 │ 1.23605   │
# │ 79  │ Sierra Leone       │ 1998  │ 1.37455    │ -1.94738 │ -7.99975  │
# │ 80  │ El Salvador        │ 1986  │ -10.4509   │ -6.30579 │ 1.53501   │
# │ 81  │ Suriname           │ 1995  │ -0.488637  │ 2.78211  │ -0.201428 │
# │ 82  │ Suriname           │ 2001  │ 1.27438    │ 5.73649  │ 1.5642    │
# │ 83  │ Slovak Republic    │ 1998  │ 1.90133    │ 6.20553  │ 5.8435    │
# │ 84  │ Slovenia           │ 2008  │ 2.84208    │ 4.3518   │ 4.00301   │
# │ 85  │ Sweden             │ 1991  │ 2.69132    │ 3.35384  │ 2.55904   │, 85×24 DataFrame. Omitted printing of 19 columns
# │ Row │ Country                      │ year  │ LGrowth5 │ LGrowth4  │ LGrowth3 │
# │     │ String                       │ Int64 │ Float64⍰ │ Float64⍰  │ Float64⍰ │
# ├─────┼──────────────────────────────┼───────┼──────────┼───────────┼──────────┤
# │ 1   │ Synthetic Angola             │ 1988  │ 3.70606  │ 7.43043   │ 3.57296  │
# │ 2   │ Synthetic Angola             │ 1991  │ 3.46411  │ 3.88971   │ 4.38904  │
# │ 3   │ Synthetic Argentina          │ 1980  │ 3.27946  │ -3.10236  │ 1.51194  │
# │ 4   │ Synthetic Austria            │ 2008  │ 0.941473 │ 2.73512   │ 2.24407  │
# │ 5   │ Synthetic Burundi            │ 1994  │ 3.72053  │ 3.04343   │ 1.92069  │
# │ 6   │ Synthetic Belgium            │ 2008  │ 0.774567 │ 3.63468   │ 2.09427  │
# │ 7   │ Synthetic Brazil             │ 1976  │ 5.55986  │ 5.91256   │ 8.15902  │
# │ 8   │ Synthetic Brazil             │ 1990  │ 7.43507  │ 6.89696   │ 4.4288   │
# │ 9   │ Synthetic Brazil             │ 1994  │ 1.97077  │ 0.0112074 │ 2.8404   │
# │ 10  │ Synthetic Botswana           │ 1984  │ 6.28428  │ 5.69842   │ 6.27767  │
# ⋮
# │ 75  │ Synthetic Paraguay           │ 1995  │ 3.99429  │ 3.2682    │ 2.06336  │
# │ 76  │ Synthetic Russian Federation │ 2008  │ 7.27246  │ 7.20788   │ 6.49672  │
# │ 77  │ Synthetic Sudan              │ 1994  │ 3.05601  │ 0.493452  │ 1.67861  │
# │ 78  │ Synthetic Sierra Leone       │ 1989  │ 0.646859 │ -3.53009  │ -2.57209 │
# │ 79  │ Synthetic Sierra Leone       │ 1998  │ 0.646859 │ -3.53009  │ -2.57209 │
# │ 80  │ Synthetic El Salvador        │ 1986  │ -13.1901 │ -6.79239  │ -5.02874 │
# │ 81  │ Synthetic Suriname           │ 1995  │ 0.28784  │ 1.9708    │ 0.471565 │
# │ 82  │ Synthetic Suriname           │ 2001  │ 2.09167  │ 5.05495   │ 1.87406  │
# │ 83  │ Synthetic Slovak Republic    │ 1998  │ 3.2043   │ 5.57931   │ 5.26753  │
# │ 84  │ Synthetic Slovenia           │ 2008  │ 2.84209  │ 4.3518    │ 4.00303  │
# │ 85  │ Synthetic Sweden             │ 1991  │ 2.69132  │ 3.35384   │ 2.55904  │)

# %%
Averages = Array{Any, 2}
# Out:
# Array{Any,2}

# %%
Averages[:,1] = zeros(3)
# Out:
# MethodError: no method matching setindex!(::Type{Array{Any,2}}, ::Array{Float64,1}, ::Colon, ::Int64)
#
# Stacktrace:
#  [1] top-level scope at In[28]:1
