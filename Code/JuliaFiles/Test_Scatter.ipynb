# %%
using DataFrames
using Plots
using StatsPlots
d= DataFrame(X= [1; 2.1; 3.5], Y = [4.4; 5.6; 3.3])
# Out:
# 3×2 DataFrame
# │ Row │ X       │ Y       │
# │     │ Float64 │ Float64 │
# ├─────┼─────────┼─────────┤
# │ 1   │ 1.0     │ 4.4     │
# │ 2   │ 2.1     │ 5.6     │
# │ 3   │ 3.5     │ 3.3     │

# %%
scatter(d[:X], d[:Y])
plot!(d[:X], d[:Y])
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[4]:1
# └ @ Core In[4]:1
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[4]:1
# └ @ Core In[4]:1
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[4]:2
# └ @ Core In[4]:2
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at In[4]:2
# └ @ Core In[4]:2
