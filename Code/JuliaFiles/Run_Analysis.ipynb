# %%
include("MasterAnalysis.jl")
# Out:
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:49
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:49
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:50
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:50
# Mean Loan Size is 2.003810902579969
# Median Loan Size is 1.2318457
# Number of Short-Term Loans for Summary Path is 457
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# │   caller = top-level scope at MasterAnalysis.jl:51
# └ @ Core C:\Users\Kevin\Documents\GitHub\IMFCrises\Code\JuliaFiles\MasterAnalysis.jl:51
# ┌ Warning: `getindex(df::DataFrame, col_ind::ColumnIndex)` is deprecated, use `df[!, col_ind]` instead.
# ...
